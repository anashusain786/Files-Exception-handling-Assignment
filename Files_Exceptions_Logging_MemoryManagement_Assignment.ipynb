# %% [markdown]
# # Files, exceptional handling, logging and memory management Questions

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages ?
#    - The main difference between interpreted and compiled languages lies in how they execute code. In compiled languages, the entire code is translated into machine language by a compiler before it is run. This means the program runs faster because it is already converted into a format the computer understands. Common examples include C, C++, and Java (though Java uses a mix of both).
#
#    - On the other hand, interpreted languages are executed line by line by an interpreter. This makes them slower in comparison, but they are easier to test and debug because you can run parts of the code without compiling the whole program. Examples include Python, JavaScript, and Ruby.
#
#    - Compiled programs are often platform-specific and need to be recompiled for different operating systems, while interpreted programs can usually run on any system with the right interpreter. In general, compiled languages are preferred for performance-heavy tasks, while interpreted ones are favored for quick development and flexibility.
#
#    - Both types have their pros and cons, and the choice depends on the nature of the project.

# %% [markdown]
# 2. What is exception handling in Python ?
#    - Exception handling in Python is a method used to handle errors that occur during the execution of a program. Instead of crashing the program when something goes wrong, Python lets you catch and deal with these errors in a controlled way.
#
#    - This is done using `try`, `except`, `else`, and `finally` blocks. You put the code that might cause an error inside the `try` block. If an error occurs, the code in the `except` block runs. If there’s no error, the code in the `else` block (if present) runs. The `finally` block always runs, no matter what, and is usually used to clean up resources.
#
#    - For example, if you try to divide a number by zero, Python will raise a `ZeroDivisionError`. With exception handling, you can catch this error and show a message to the user instead of crashing the program.
#
#    - It’s a useful feature because it makes your programs more robust and user-friendly. Rather than stopping everything when an unexpected situation occurs, you can manage the error and continue smoothly.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling ?
#    - The `finally` block in exception handling is used to write code that should run no matter what happens in the `try` and `except` blocks. Its main purpose is to ensure that certain steps are always carried out, whether an error occurs or not.
#
#    - For example, if you're working with a file, you might want to make sure the file is closed properly. Even if an error happens while reading the file, the `finally` block will still run and close the file safely.
#
#    - It’s especially useful when working with resources like files, database connections, or network links, where cleanup is necessary to avoid problems later in the program.
#
#    - The key point is that the `finally` block runs every time, regardless of whether an exception was raised, handled, or not raised at all. It helps maintain a clean and predictable flow in programs by handling tasks that must always be done.

# %% [markdown]
# 4. What is logging in Python ?
#    - Logging in Python is a way to keep track of events that happen when a program runs. Instead of using print statements, which are mainly for debugging during development, logging helps record messages with different levels of importance, like info, warning, error, or critical.
#
#    - Python has a built-in `logging` module that allows you to create logs and store them in files or display them on the screen. This makes it easier to monitor what your program is doing, especially when it's running in production or handling complex tasks.
#
#    - You can configure logging to show messages based on their severity level. For example, you might only want to log warnings and errors, and ignore general info messages. It also helps track bugs or unexpected behavior without interrupting the flow of the program.
#
#    - Using logging is a good habit because it gives you better control and insight into your code, especially in larger applications where tracking issues can be more difficult.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python ?
#    - The `__del__` method in Python is a special method that gets called automatically when an object is about to be destroyed. It's also known as a destructor. Its main use is to clean up resources the object might be using before the memory is released.
#
#    - For instance, if an object opened a file or created a network connection, the `__del__` method can be used to close the file or disconnect the network properly. This helps avoid memory leaks or leaving resources hanging.
#
#    - It’s important to know that Python handles memory management using a garbage collector, so you usually don’t need to manage memory manually. But the `__del__` method can still be useful when you need to free up non-memory resources like files or sockets.
#
#    - However, relying too much on `__del__` is not always a good idea because its execution time isn't guaranteed, especially when there are circular references. It's better to use context managers (`with` statement) for handling cleanup tasks when possible.

# %% [markdown]
# 6. What is the difference between import and from ... import in Python ?
#    - In Python, both `import` and `from ... import` are used to bring in code from external modules, but they work a bit differently.
#
#    - When you use `import module_name`, you bring in the entire module. To access anything from that module, you have to use the module name as a prefix. For example, `import math` means you’ll use functions like `math.sqrt()`.
#
#    - On the other hand, `from module_name import something` allows you to import a specific part of the module directly. So if you write `from math import sqrt`, you can just use `sqrt()` without the `math.` prefix.
#
#    - The main difference is in how you access the functions or variables after importing. Using `import` keeps the module’s namespace intact, which helps avoid name conflicts. But `from ... import` can make your code cleaner when you only need a few things.
#
#    - Both have their use cases, and choosing one depends on readability, clarity, and whether you're importing a lot or just a few specific items.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python ?
#    - In Python, you can handle multiple exceptions by using multiple `except` blocks or combining them in a single block. This helps manage different types of errors in a clean and organized way.
#
#    - If you expect different kinds of errors, you can write separate `except` blocks for each one. For example, one for `ValueError` and another for `ZeroDivisionError`. This allows you to respond differently depending on what went wrong.
#
#    - You can also handle multiple exceptions in a single block by using a tuple. For example: `except (ValueError, TypeError):` will catch either error and run the same code for both.
#
#    - It’s a good idea to place more specific exceptions first, and more general ones later. This keeps the handling clear and avoids unexpected behavior.
#
#    - This method keeps your program from crashing and helps deal with unexpected inputs or bugs more gracefully.

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python ?
#    - The `with` statement in Python is mainly used to work with files in a safe and clean way. Its purpose is to automatically handle opening and closing the file, so you don’t have to worry about forgetting to close it yourself.
#
#    - When you open a file using just `open()`, you have to manually call `close()` at the end. If an error happens before that point, the file might stay open, which can cause problems like memory leaks or locked resources.
#
#    - Using `with open(...) as file:` ensures that the file is properly closed after the block of code runs, even if there’s an error. It’s like a shortcut that handles setup and cleanup for you.
#
#    - This makes your code shorter, neater, and less error-prone. It’s especially useful when dealing with large programs where managing resources properly becomes more important.
#
#    - In short, `with` helps you write more reliable and readable file-handling code.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing ?
#    - Multithreading and multiprocessing are both techniques used to perform multiple tasks at the same time, but they work differently under the hood.
#
#    - Multithreading involves running multiple threads within the same process. All threads share the same memory space, which makes it lightweight and good for tasks that involve a lot of waiting, like downloading files or handling user input. However, because of Python’s Global Interpreter Lock (GIL), true parallel execution of threads is limited.
#
#    - Multiprocessing, on the other hand, uses separate processes. Each process runs independently and has its own memory space. This allows for real parallelism and is better suited for CPU-intensive tasks, like data processing or calculations.
#
#    - The key difference is that threads share memory while processes do not. Threads are faster to start but can run into issues with shared data, while processes are heavier but avoid most of those problems.
#
#    - Choosing between them depends on the kind of task you’re trying to speed up—IO-bound tasks benefit from multithreading, while CPU-bound ones are better handled with multiprocessing.

# %% [markdown]
# 10. What are the advantages of using logging in a program ?
#     - Using logging in a program has several advantages that go beyond simple debugging. It provides a structured way to track what’s happening in your code while it runs, which is especially helpful in larger or long-running applications.
#
#     - One major benefit is that it helps identify errors or unexpected behavior without stopping the program. Instead of using `print()` statements everywhere, logging allows you to control the level of detail shown—like info, warning, error, or critical messages.
#
#     - You can also save logs to a file, making it easier to review what happened during execution, especially when something goes wrong in production. This is useful for diagnosing issues after the fact.
#
#     - Logging improves code readability and keeps the output clean. It also allows teams to monitor applications in real time, making maintenance and updates smoother.
#
#     - Overall, it adds professionalism, reliability, and control to your code, making it easier to manage and troubleshoot over time.

# %% [markdown]
# 11. What is memory management in Python ?
#     - Memory management in Python refers to how the language handles the allocation and release of memory while a program runs. It ensures that the memory is used efficiently and that unused memory is freed up properly.
#
#     - Python does this automatically using a built-in system called the garbage collector. When you create objects or variables, Python allocates memory for them. Once those objects are no longer needed or referenced, the garbage collector cleans them up to free that memory for future use.
#
#     - Behind the scenes, Python uses something called reference counting. Each object keeps track of how many references point to it. When that count drops to zero, it means no part of the code is using it anymore, so it can be safely removed.
#
#     - There’s also a cyclic garbage collector that handles cases where objects reference each other in a loop, which simple reference counting can’t catch.
#
#     - This automatic management helps prevent memory leaks and makes programming in Python easier, since you don’t have to manually free memory like in some other languages.

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python ?
#     - Exception handling in Python follows a few basic steps to catch and manage errors smoothly without crashing the program.
#
#     - First, you use a `try` block to write the code that might cause an error. This is where you place the risky part—like dividing numbers, opening files, or converting data types.
#
#     - If something goes wrong in the `try` block, Python jumps to the `except` block. Here, you define how to handle specific exceptions, such as `ZeroDivisionError` or `ValueError`. You can have multiple `except` blocks to deal with different types of errors.
#
#     - Optionally, you can use an `else` block, which runs only if no exception occurred in the `try` section. This is useful when you want to keep success logic separate from error handling.
#
#     - Finally, there’s the `finally` block. This runs no matter what—whether an error happened or not. It’s usually used to release resources like closing files or network connections.
#
#     - These steps help you manage errors in a clean and structured way, keeping your program stable and user-friendly.

# %% [markdown]
# 13. Why is memory management important in Python ?
#     - Memory management is important in Python because it helps your program run efficiently and reliably. Every time you create a variable or an object, it takes up space in memory. If that memory isn’t managed properly, it can lead to issues like your program slowing down or even crashing.
#
#     - Python handles most memory tasks automatically, but understanding its importance can help you write better code. When memory is used unnecessarily or not released when it’s no longer needed, it can cause memory leaks. This becomes a serious problem in large or long-running programs.
#
#     - Good memory management ensures that the system resources are used wisely, keeping performance steady even as your program grows. It also helps avoid bugs that are hard to track, especially when objects stay in memory longer than needed.
#
#     - By using features like garbage collection and reference counting, Python makes memory handling easier, but developers still need to be mindful—like avoiding unnecessary global variables or large unused data structures.
#
#     - In short, efficient memory use keeps your code fast, stable, and clean.

# %% [markdown]
# 14. What is the role of try and except in exception handling ?
#     - The `try` and `except` blocks play a key role in handling errors in Python. They help your program deal with unexpected situations without crashing.
#
#     - The `try` block is where you put the code that might raise an error. It’s like saying, “Try to run this code, but if something goes wrong, be ready to handle it.” Common examples include dividing numbers, opening files, or converting data types.
#
#     - If an error happens inside the `try` block, Python immediately stops running that part and jumps to the `except` block. In the `except` block, you write how the program should respond to that specific error. This could be showing a user-friendly message, skipping the error, or logging it.
#
#     - Without `try` and `except`, your whole program could crash on a single mistake. But with them, you can manage the problem and keep the rest of your program running smoothly.
#
#     - It’s a simple but powerful way to make your code more reliable and user-friendly.

# %% [markdown]
# 15. How does Python's garbage collection system work ?
#     - Python's garbage collection system is responsible for automatically managing memory by removing objects that are no longer in use. This process helps ensure that your program doesn’t waste memory or slow down over time.
#
#     - At the core of this system is *reference counting*. Every object in Python keeps track of how many variables or other objects are referring to it. When this count drops to zero, it means nothing is using that object anymore, so Python immediately frees the memory.
#
#     - But reference counting alone isn't perfect. Sometimes, two or more objects refer to each other, forming a cycle, even though nothing outside is using them. Python handles this with a built-in *cyclic garbage collector*, which scans for such reference loops and clears them.
#
#     - This garbage collection happens automatically in the background. You usually don’t notice it, but it plays a big role in keeping your program efficient and stable. It’s one of the reasons Python is considered a high-level, developer-friendly language.

# %% [markdown]
# 16. What is the purpose of the else block in exception handling ?
#     - The `else` block in exception handling is used to write code that should run only if no exceptions were raised in the `try` block. It's a way to separate the normal flow of the program from the error-handling part.
#
#     - When Python executes a `try` block and no error occurs, it skips the `except` block and moves directly to the `else` block if one is present. This helps keep your code cleaner and more organized, especially when you want to make it clear what should happen only when everything goes right.
#
#     - For example, you might try to open a file in the `try` block. If the file opens without error, the `else` block could handle reading its contents. But if opening the file fails, the `except` block handles the problem instead, and the `else` part is skipped.
#
#     - Using `else` in this way improves readability and helps avoid accidentally running code that should not execute after a failure. It adds clarity to the flow of logic when working with exceptions.

# %% [markdown]
# 17. What are the common logging levels in Python ?
#     - In Python, logging levels are used to indicate the importance or severity of a message. They help you filter logs and decide what kind of messages should be recorded or displayed during the program's execution.
#
#     - There are five main logging levels commonly used:
#
#      *   **DEBUG** – This is the lowest level. It’s used for detailed information, typically useful only for developers while debugging.
#      *   **INFO** – Used to confirm that things are working as expected. It shows general events like the progress of the program.
#      *   **WARNING** – Indicates something unexpected happened, or there might be an issue soon, but the program is still running fine.
#      *   **ERROR** – This is for more serious problems where something went wrong and the program couldn’t perform a part of its task.
#      *   **CRITICAL** – The highest level. It means a serious error has occurred, and the program might not be able to continue running.
#
#     - These levels help you control what gets logged, depending on the situation. For example, in development, you might use DEBUG, but in production, you might only log WARNING and above.

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python ?
#     - `os.fork()` and the `multiprocessing` module in Python are both used to create new processes, but they work in different ways and are used in different scenarios.
#
#     - `os.fork()` is a low-level system call available only on Unix-based systems like Linux and macOS. It creates a child process by duplicating the current process. After the fork, both parent and child continue running the same code from the point where `fork()` was called. It's powerful but requires more careful handling, since you're directly dealing with the process behavior.
#
#     - On the other hand, `multiprocessing` is a high-level module that works on both Windows and Unix systems. It allows you to spawn processes easily by defining target functions. It also provides tools like `Queue`, `Pipe`, and `Pool` to manage communication and synchronization between processes.
#
#     - The key difference is that `multiprocessing` is cross-platform and more user-friendly, while `os.fork()` is system-dependent and lower-level. If you're writing portable code or want a cleaner interface, `multiprocessing` is usually the better choice.

# %% [markdown]
# 19. What is the importance of closing a file in Python ?
#     - Closing a file in Python is important because it ensures that all the changes you've made to the file are saved properly and system resources are released. When a file is open, it takes up memory and other system resources. If you don’t close it, those resources stay locked until the program ends, which can cause problems in larger applications.
#
#     - When writing to a file, data is often stored in a temporary buffer before it's actually written. If the file isn’t closed, some of that data might never be saved, leading to incomplete or corrupted files.
#
#     - Leaving files open can also prevent other programs or parts of your own code from accessing them. This can lead to bugs that are hard to trace.
#
#     - Closing files shows good coding practice and helps keep your program stable and efficient. An even better way to handle this is by using the `with` statement, which automatically closes the file when you're done.

# %% [markdown]
# 20. What is the difference between file.read() and file.readline() in Python ?
#     - The main difference between `file.read()` and `file.readline()` in Python lies in how much content they read from a file.
#
#     - `file.read()` reads the entire content of the file as a single string. It pulls in everything—from the first character to the last—unless you specify a size limit. This is useful when you want to process the whole file at once. However, for very large files, it can use a lot of memory.
#
#     - On the other hand, `file.readline()` reads just one line at a time. Each time you call it, it returns the next line from the file, including the newline character at the end. This method is handy when you're working with large files and want to read them line by line without loading the entire file into memory.
#
#     - So, `read()` is good for smaller files or when you need everything at once, while `readline()` is better for handling big files or when you need to process data line by line.

# %% [markdown]
# 21. What is the logging module in Python used for ?
#     - The `logging` module in Python is used to record messages that describe what’s happening in a program. It helps developers track the flow of a program and understand its behavior, especially when things go wrong.
#
#     - Instead of using print statements, which are meant for quick checks, `logging` provides a more structured and flexible way to report information. You can log messages with different levels like DEBUG, INFO, WARNING, ERROR, and CRITICAL, depending on how serious the message is.
#
#     - This module also lets you decide where the messages should go. They can be shown on the screen, saved in a file, or even sent over the network. You can also format the messages to include things like timestamps, line numbers, or module names.
#
#     - Overall, the `logging` module is a powerful tool for monitoring and debugging programs, especially as they grow more complex or move into production environments. It keeps your code cleaner and makes it easier to spot issues when they arise.

# %% [markdown]
# 22. What is the os module in Python used for in file handling ?
#     - The `os` module in Python plays a key role in file handling by giving access to functions that interact with the operating system. It allows you to work with files and directories in a way that’s independent of the platform you’re using.
#
#     - With the `os` module, you can perform tasks like creating new folders using `os.mkdir()`, removing files with `os.remove()`, renaming files or folders using `os.rename()`, and checking if a file or directory exists using `os.path.exists()`.
#
#     - It also lets you list the contents of a directory using `os.listdir()` and navigate through folders with `os.chdir()` or get the current working directory using `os.getcwd()`.
#
#     - These features are especially useful when writing programs that need to manage files automatically, such as backup scripts, data processing tools, or applications that generate or move files.
#
#     - In short, the `os` module gives you the tools to control files and directories directly from your Python code, making file management much easier and more efficient.

# %% [markdown]
# 23. What are the challenges associated with memory management in Python ?
#     - While Python handles memory management automatically, there are still a few challenges that developers need to be aware of.
#
#     - One issue is **memory leaks**, which happen when objects that are no longer needed remain in memory because something is still referencing them. This can slowly eat up system resources, especially in long-running programs.
#
#     - Another challenge is **circular references**, where two or more objects reference each other, preventing Python’s reference counting from clearing them. Although Python has a cyclic garbage collector to handle this, it doesn’t always catch everything efficiently.
#
#     - **Unnecessary memory usage** can also be a problem. For example, holding large data structures in memory when they’re no longer needed can slow down performance or cause the program to crash if memory runs out.
#
#     - Finally, Python’s memory handling isn’t always predictable, especially when working with third-party libraries or extensions written in C. These may bypass Python’s garbage collection system entirely.
#
#     - So, even though Python makes memory management easier, being mindful of how memory is used in your code is still important to keep programs efficient and stable.

# %% [markdown]
# 24. How do you raise an exception manually in Python ?
#     - In Python, you can raise an exception manually using the `raise` keyword. This is useful when you want to stop the program or signal that something has gone wrong, even if Python doesn’t detect it automatically.
#
#     - For example, if a user enters a negative number where only positives are allowed, you can raise an error yourself instead of letting the program continue with bad input.
#
#     - To raise an exception, you simply use `raise` followed by the type of exception you want to trigger. You can also include a custom message to explain what went wrong. For instance:
#
#       * raise ValueError("Negative numbers are not allowed")
#
#     - You can raise built-in exceptions like `TypeError`, `ValueError`, or even create your own custom exception classes.
#
#     - Manually raising exceptions helps make your code safer and easier to debug by catching issues early and handling them properly.

# %% [markdown]
# 25. Why is it important to use multithreading in certain applications ?
#     - Multithreading is important in certain applications because it allows a program to do multiple things at the same time without waiting for one task to finish before starting another. This is especially useful in situations where tasks spend time waiting, like reading from a file, making network requests, or handling user input.
#
#     - By using threads, a program can stay responsive. For example, in a chat application, one thread can handle receiving messages while another deals with sending them, so the user doesn’t experience delays.
#
#     - Multithreading also helps improve performance in I/O-bound applications, where the CPU isn’t the bottleneck. It makes better use of system resources and can result in faster, smoother execution.
#
#     - It’s commonly used in games, web servers, and desktop applications where multiple operations need to happen at once. Without it, programs can freeze or slow down, leading to a poor user experience.
#
#     - So, multithreading is a smart way to make applications more efficient and responsive in the right scenarios.

# %% [markdown]
# # Practical Questions

# %%
# How can you open a file for writing in Python and write a string to it

with open('example.txt', 'w') as file:
    file.write("Hello, this is a sample text.")

# Show the output on the screen
print("Hello, this is a sample text.")
# Out:
# Hello, this is a sample text.

# %%
# Write a Python program to read the contents of a file and print each line

with open('example.txt', 'r') as file:
    for line in file:
        print(line)
# Out:
# Hello, this is a sample text.

# %%
# How would you handle a case where the file doesn't exist while trying to open it for reading

try:
    with open('example.txt', 'r') as file:
        for line in file:
            print(line, end='')  # This prints each line from the file
except FileNotFoundError:
    print("The file does not exist. Please check the file name or path.")
# Out:
# Hello, this is a sample text.

# %%
# Write a Python script that reads from one file and writes its content to another file

# Read from source file and write to destination file
try:
    with open('source.txt', 'r') as source_file:
        content = source_file.read()

    with open('destination.txt', 'w') as destination_file:
        destination_file.write(content)

    print("File copied successfully.")
except FileNotFoundError:
    print("The source file does not exist.")
# Out:
# The source file does not exist.

# %%
# How would you catch and handle division by zero error in Python

try:
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    result = a / b
    print("Result:", result)
except ZeroDivisionError:
    print("Error: You cannot divide by zero.")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# Error: You cannot divide by zero.

# %%
# Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging

# Configure logging
logging.basicConfig(filename='error_log.txt', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    result = a / b
    print("Result:", result)
except ZeroDivisionError as e:
    print("Cannot divide by zero.")
    logging.error("Division by zero error occurred: %s", e)
# Out:
# Enter numerator: 10
# Enter denominator: 0
# ERROR:root:Division by zero error occurred: division by zero
# Cannot divide by zero.

# %%
#  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

import logging

logging.basicConfig(level=logging.INFO)

logging.info("This is an info message")
logging.error("This is an error message")
logging.warning("This is a warning message")
# Out:
# ERROR:root:This is an error message
# WARNING:root:This is a warning message

# %%
# Write a program to handle a file opening error using exception handling

try:
    # Try to open a file that may not exist
    with open('myfile.txt', 'r') as file:
        content = file.read()
        print("File content:")
        print(content)

except FileNotFoundError:
    print("Error: The file 'myfile.txt' was not found.")
except PermissionError:
    print("Error: You don't have permission to open this file.")
except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Error: The file 'myfile.txt' was not found.

# %%
#  How can you read a file line by line and store its content in a list in Python

lines = []

with open('example.txt', 'r') as file:
    for line in file:
        lines.append(line)

print(lines)
# Out:
# ['Hello, this is a sample text.']

# %%
#  How can you append data to an existing file in Python

# Open the file in append mode
with open('example.txt', 'a') as file:
    file.write("This is a new line added to the file.\n")

# %%
# Write a Python program that uses a try-except block to handle an error when attempting to access a  dictionary key that doesn't exist

# Sample dictionary
student = {
    "name": "Ananya",
    "age": 21,
    "course": "AI & Data Science"
}

try:
    # Trying to access a key that might not exist
    print("Student's grade:", student["grade"])
except KeyError:
    print("Error: 'grade' key not found in the dictionary.")
# Out:
# Error: 'grade' key not found in the dictionary.

# %%
# Write a program that demonstrates using multiple except blocks to handle different types of exceptions

try:
    # Get input from the user
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))

    # Perform division
    result = num1 / num2
    print("Result:", result)

    # Access a list element
    my_list = [10, 20, 30]
    index = int(input("Enter an index (0-2): "))
    print("Value at index:", my_list[index])

except ZeroDivisionError:
    print("Error: You cannot divide by zero.")

except ValueError:
    print("Error: Please enter a valid number.")

except IndexError:
    print("Error: Index is out of range.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter a number: 10
# Enter another number: 0
# Error: You cannot divide by zero.

# %%
# How would you check if a file exists before attempting to read it in Python

import os

if os.path.exists('example.txt'):
    with open('example.txt', 'r') as file:
        content = file.read()
        print("File content:")
        print(content)
else:
    print("The file does not exist.")
# Out:
# File content:
# Hello, this is a sample text.This is a new line added to the file.
# This is a new line added to the file.

# %%
# Write a program that uses the logging module to log both informational and error messages

import logging

# Configure the logging settings
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,  # Captures INFO, WARNING, ERROR, etc.
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Log an informational message
logging.info("Program started successfully.")

try:
    # Simulate some operation
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    result = a / b
    logging.info(f"Division successful. Result: {result}")
    print("Result:", result)

except ZeroDivisionError:
    logging.error("Attempted division by zero.")
    print("Error: Cannot divide by zero.")

except ValueError:
    logging.error("Invalid input provided. Non-integer value entered.")
    print("Error: Please enter valid integers.")

except Exception as e:
    logging.error(f"Unexpected error occurred: {e}")
    print("An unexpected error occurred.")
# Out:
# Enter numerator: 10
# Enter denominator: 2
# Result: 5.0

# %%
# Write a Python program that prints the content of a file and handles the case when the file is empty

try:
    with open('example.txt', 'r') as file:
        content = file.read()
        if content.strip() == "":
            print("The file is empty.")
        else:
            print("File content:")
            print(content)
except FileNotFoundError:
    print("Error: The file 'example.txt' does not exist.")
except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# File content:
# Hello, this is a sample text.This is a new line added to the file.
# This is a new line added to the file.

# %%
# %pip install memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.11/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)

# %% [markdown]
# After installing the library, you can run the original cell again to use the memory profiler.

# %%
# Demonstrate how to use memory profiling to check the memory usage of a small program

"""To check the memory usage of a small Python program, you can use the memory_profiler module. It's a helpful tool to see how much memory your code is using, especially line by line."""
from memory_profiler import profile

@profile
def my_function():
    numbers = [i for i in range(100000)]  # Creating a big list
    squares = [x ** 2 for x in numbers]
    return sum(squares)

if __name__ == "__main__":
    my_function()
# Out:
# ERROR: Could not find file /tmp/ipython-input-36-788439594.py

# %%
#  Write a Python program to create and write a list of numbers to a file, one number per line

# Create a list of numbers
numbers = [10, 20, 30, 40, 50]

# Open a file in write mode
with open('numbers.txt', 'w') as file:
    for number in numbers:
        file.write(str(number) + '\n')

print("Numbers written to 'numbers.txt' successfully.")
# Out:
# Numbers written to 'numbers.txt' successfully.

# %%
#  How would you implement a basic logging setup that logs to a file with rotation after 1MB

import logging
from logging.handlers import RotatingFileHandler

# Set up a rotating file handler
log_handler = RotatingFileHandler(
    'app.log',           # Log file name
    maxBytes=1_000_000,  # 1MB = 1,000,000 bytes
    backupCount=3        # Keep 3 old log files as backup
)

# Set logging format
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
log_handler.setFormatter(formatter)

# Get the logger and set level
logger = logging.getLogger('my_logger')
logger.setLevel(logging.DEBUG)
logger.addHandler(log_handler)

# Sample log messages
logger.info("Logging started.")
for i in range(10000):
    logger.debug(f"Debug message {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:my_logger:Debug message 5000
# DEBUG:my_logger:Debug message 5001
# DEBUG:my_logger:Debug message 5002
# DEBUG:my_logger:Debug message 5003
# DEBUG:my_logger:Debug message 5004
# DEBUG:my_logger:Debug message 5005
# DEBUG:my_logger:Debug message 5006
# DEBUG:my_logger:Debug message 5007
# DEBUG:my_logger:Debug message 5008
# DEBUG:my_logger:Debug message 5009
# DEBUG:my_logger:Debug message 5010
# DEBUG:my_logger:Debug message 5011
# DEBUG:my_logger:Debug message 5012
# DEBUG:my_logger:Debug message 5013
# DEBUG:my_logger:Debug message 5014
# DEBUG:my_logger:Debug message 5015
# DEBUG:my_logger:Debug message 5016
# DEBUG:my_logger:Debug message 5017
# DEBUG:my_logger:Debug message 5018
# DEBUG:my_logger:Debug message 5019
# DEBUG:my_logger:Debug message 5020
# DEBUG:my_logger:Debug message 5021
# DEBUG:my_logger:Debug message 5022
# DEBUG:my_logger:Debug message 5023
# DEBUG:my_logger:Debug message 5024
# DEBUG:my_logger:Debug message 5025
# DEBUG:my_logger:Debug message 5026
# DEBUG:my_logger:Debug message 5027
# DEBUG:my_logger:Debug message 5028
# DEBUG:my_logger:Debug message 5029
# DEBUG:my_logger:Debug message 5030
# DEBUG:my_logger:Debug message 5031
# DEBUG:my_logger:Debug message 5032
# DEBUG:my_logger:Debug message 5033
# DEBUG:my_logger:Debug message 5034
# DEBUG:my_logger:Debug message 5035
# DEBUG:my_logger:Debug message 5036
# DEBUG:my_logger:Debug message 5037
# DEBUG:my_logger:Debug message 5038
# DEBUG:my_logger:Debug message 5039
# DEBUG:my_logger:Debug message 5040
# DEBUG:my_logger:Debug message 5041
# DEBUG:my_logger:Debug message 5042
# DEBUG:my_logger:Debug message 5043
# DEBUG:my_logger:Debug message 5044
# DEBUG:my_logger:Debug message 5045
# DEBUG:my_logger:Debug message 5046
# DEBUG:my_logger:Debug message 5047
# DEBUG:my_logger:Debug message 5048
# DEBUG:my_logger:Debug message 5049
# DEBUG:my_logger:Debug message 5050
# DEBUG:my_logger:Debug message 5051
# DEBUG:my_logger:Debug message 5052
# DEBUG:my_logger:Debug message 5053
# DEBUG:my_logger:Debug message 5054
# DEBUG:my_logger:Debug message 5055
# DEBUG:my_logger:Debug message 5056
# DEBUG:my_logger:Debug message 5057
# DEBUG:my_logger:Debug message 5058
# DEBUG:my_logger:Debug message 5059
# DEBUG:my_logger:Debug message 5060
# DEBUG:my_logger:Debug message 5061
# DEBUG:my_logger:Debug message 5062
# DEBUG:my_logger:Debug message 5063
# DEBUG:my_logger:Debug message 5064
# DEBUG:my_logger:Debug message 5065
# DEBUG:my_logger:Debug message 5066
# DEBUG:my_logger:Debug message 5067
# DEBUG:my_logger:Debug message 5068
# DEBUG:my_logger:Debug message 5069
# DEBUG:my_logger:Debug message 5070
# DEBUG:my_logger:Debug message 5071
# DEBUG:my_logger:Debug message 5072
# DEBUG:my_logger:Debug message 5073
# DEBUG:my_logger:Debug message 5074
# DEBUG:my_logger:Debug message 5075
# DEBUG:my_logger:Debug message 5076
# DEBUG:my_logger:Debug message 5077
# DEBUG:my_logger:Debug message 5078
# DEBUG:my_logger:Debug message 5079
# DEBUG:my_logger:Debug message 5080
# DEBUG:my_logger:Debug message 5081
# DEBUG:my_logger:Debug message 5082
# DEBUG:my_logger:Debug message 5083
# DEBUG:my_logger:Debug message 5084
# DEBUG:my_logger:Debug message 5085
# DEBUG:my_logger:Debug message 5086
# DEBUG:my_logger:Debug message 5087
# DEBUG:my_logger:Debug message 5088
# DEBUG:my_logger:Debug message 5089
# DEBUG:my_logger:Debug message 5090
# DEBUG:my_logger:Debug message 5091
# DEBUG:my_logger:Debug message 5092
# DEBUG:my_logger:Debug message 5093
# DEBUG:my_logger:Debug message 5094
# DEBUG:my_logger:Debug message 5095
# DEBUG:my_logger:Debug message 5096
# DEBUG:my_logger:Debug message 5097
# DEBUG:my_logger:Debug message 5098
# DEBUG:my_logger:Debug message 5099
# DEBUG:my_logger:Debug message 5100
# DEBUG:my_logger:Debug message 5101
# DEBUG:my_logger:Debug message 5102
# DEBUG:my_logger:Debug message 5103
# DEBUG:my_logger:Debug message 5104
# DEBUG:my_logger:Debug message 5105
# DEBUG:my_logger:Debug message 5106
# DEBUG:my_logger:Debug message 5107
# DEBUG:my_logger:Debug message 5108
# DEBUG:my_logger:Debug message 5109
# DEBUG:my_logger:Debug message 5110
# DEBUG:my_logger:Debug message 5111
# DEBUG:my_logger:Debug message 5112
# DEBUG:my_logger:Debug message 5113
# DEBUG:my_logger:Debug message 5114
# DEBUG:my_logger:Debug message 5115
# DEBUG:my_logger:Debug message 5116
# DEBUG:my_logger:Debug message 5117
# DEBUG:my_logger:Debug message 5118
# DEBUG:my_logger:Debug message 5119
# DEBUG:my_logger:Debug message 5120
# DEBUG:my_logger:Debug message 5121
# DEBUG:my_logger:Debug message 5122
# DEBUG:my_logger:Debug message 5123
# DEBUG:my_logger:Debug message 5124
# DEBUG:my_logger:Debug message 5125
# DEBUG:my_logger:Debug message 5126
# DEBUG:my_logger:Debug message 5127
# DEBUG:my_logger:Debug message 5128
# DEBUG:my_logger:Debug message 5129
# DEBUG:my_logger:Debug message 5130
# DEBUG:my_logger:Debug message 5131
# DEBUG:my_logger:Debug message 5132
# DEBUG:my_logger:Debug message 5133
# DEBUG:my_logger:Debug message 5134
# DEBUG:my_logger:Debug message 5135
# DEBUG:my_logger:Debug message 5136
# DEBUG:my_logger:Debug message 5137
# DEBUG:my_logger:Debug message 5138
# DEBUG:my_logger:Debug message 5139
# DEBUG:my_logger:Debug message 5140
# DEBUG:my_logger:Debug message 5141
# DEBUG:my_logger:Debug message 5142
# DEBUG:my_logger:Debug message 5143
# DEBUG:my_logger:Debug message 5144
# DEBUG:my_logger:Debug message 5145
# DEBUG:my_logger:Debug message 5146
# DEBUG:my_logger:Debug message 5147
# DEBUG:my_logger:Debug message 5148
# DEBUG:my_logger:Debug message 5149
# DEBUG:my_logger:Debug message 5150
# DEBUG:my_logger:Debug message 5151
# DEBUG:my_logger:Debug message 5152
# DEBUG:my_logger:Debug message 5153
# DEBUG:my_logger:Debug message 5154
# DEBUG:my_logger:Debug message 5155
# DEBUG:my_logger:Debug message 5156
# DEBUG:my_logger:Debug message 5157
# DEBUG:my_logger:Debug message 5158
# DEBUG:my_logger:Debug message 5159
# DEBUG:my_logger:Debug message 5160
# DEBUG:my_logger:Debug message 5161
# DEBUG:my_logger:Debug message 5162
# DEBUG:my_logger:Debug message 5163
# DEBUG:my_logger:Debug message 5164
# DEBUG:my_logger:Debug message 5165
# DEBUG:my_logger:Debug message 5166
# DEBUG:my_logger:Debug message 5167
# DEBUG:my_logger:Debug message 5168
# DEBUG:my_logger:Debug message 5169
# DEBUG:my_logger:Debug message 5170
# DEBUG:my_logger:Debug message 5171
# DEBUG:my_logger:Debug message 5172
# DEBUG:my_logger:Debug message 5173
# DEBUG:my_logger:Debug message 5174
# DEBUG:my_logger:Debug message 5175
# DEBUG:my_logger:Debug message 5176
# DEBUG:my_logger:Debug message 5177
# DEBUG:my_logger:Debug message 5178
# DEBUG:my_logger:Debug message 5179
# DEBUG:my_logger:Debug message 5180
# DEBUG:my_logger:Debug message 5181
# DEBUG:my_logger:Debug message 5182
# DEBUG:my_logger:Debug message 5183
# DEBUG:my_logger:Debug message 5184
# DEBUG:my_logger:Debug message 5185
# DEBUG:my_logger:Debug message 5186
# DEBUG:my_logger:Debug message 5187
# DEBUG:my_logger:Debug message 5188
# DEBUG:my_logger:Debug message 5189
# DEBUG:my_logger:Debug message 5190
# DEBUG:my_logger:Debug message 5191
# DEBUG:my_logger:Debug message 5192
# DEBUG:my_logger:Debug message 5193
# DEBUG:my_logger:Debug message 5194
# DEBUG:my_logger:Debug message 5195
# DEBUG:my_logger:Debug message 5196
# DEBUG:my_logger:Debug message 5197
# DEBUG:my_logger:Debug message 5198
# DEBUG:my_logger:Debug message 5199
# DEBUG:my_logger:Debug message 5200
# DEBUG:my_logger:Debug message 5201
# DEBUG:my_logger:Debug message 5202
# DEBUG:my_logger:Debug message 5203
# DEBUG:my_logger:Debug message 5204
# DEBUG:my_logger:Debug message 5205
# DEBUG:my_logger:Debug message 5206
# DEBUG:my_logger:Debug message 5207
# DEBUG:my_logger:Debug message 5208
# DEBUG:my_logger:Debug message 5209
# DEBUG:my_logger:Debug message 5210
# DEBUG:my_logger:Debug message 5211
# DEBUG:my_logger:Debug message 5212
# DEBUG:my_logger:Debug message 5213
# DEBUG:my_logger:Debug message 5214
# DEBUG:my_logger:Debug message 5215
# DEBUG:my_logger:Debug message 5216
# DEBUG:my_logger:Debug message 5217
# DEBUG:my_logger:Debug message 5218
# DEBUG:my_logger:Debug message 5219
# DEBUG:my_logger:Debug message 5220
# DEBUG:my_logger:Debug message 5221
# DEBUG:my_logger:Debug message 5222
# DEBUG:my_logger:Debug message 5223
# DEBUG:my_logger:Debug message 5224
# DEBUG:my_logger:Debug message 5225
# DEBUG:my_logger:Debug message 5226
# DEBUG:my_logger:Debug message 5227
# DEBUG:my_logger:Debug message 5228
# DEBUG:my_logger:Debug message 5229
# DEBUG:my_logger:Debug message 5230
# DEBUG:my_logger:Debug message 5231
# DEBUG:my_logger:Debug message 5232
# DEBUG:my_logger:Debug message 5233
# DEBUG:my_logger:Debug message 5234
# DEBUG:my_logger:Debug message 5235
# DEBUG:my_logger:Debug message 5236
# DEBUG:my_logger:Debug message 5237
# DEBUG:my_logger:Debug message 5238
# DEBUG:my_logger:Debug message 5239
# DEBUG:my_logger:Debug message 5240
# DEBUG:my_logger:Debug message 5241
# DEBUG:my_logger:Debug message 5242
# DEBUG:my_logger:Debug message 5243
# DEBUG:my_logger:Debug message 5244
# DEBUG:my_logger:Debug message 5245
# DEBUG:my_logger:Debug message 5246
# DEBUG:my_logger:Debug message 5247
# DEBUG:my_logger:Debug message 5248
# DEBUG:my_logger:Debug message 5249
# DEBUG:my_logger:Debug message 5250
# DEBUG:my_logger:Debug message 5251
# DEBUG:my_logger:Debug message 5252
# DEBUG:my_logger:Debug message 5253
# DEBUG:my_logger:Debug message 5254
# DEBUG:my_logger:Debug message 5255
# DEBUG:my_logger:Debug message 5256
# DEBUG:my_logger:Debug message 5257
# DEBUG:my_logger:Debug message 5258
# DEBUG:my_logger:Debug message 5259
# DEBUG:my_logger:Debug message 5260
# DEBUG:my_logger:Debug message 5261
# DEBUG:my_logger:Debug message 5262
# DEBUG:my_logger:Debug message 5263
# DEBUG:my_logger:Debug message 5264
# DEBUG:my_logger:Debug message 5265
# DEBUG:my_logger:Debug message 5266
# DEBUG:my_logger:Debug message 5267
# DEBUG:my_logger:Debug message 5268
# DEBUG:my_logger:Debug message 5269
# DEBUG:my_logger:Debug message 5270
# DEBUG:my_logger:Debug message 5271
# DEBUG:my_logger:Debug message 5272
# DEBUG:my_logger:Debug message 5273
# DEBUG:my_logger:Debug message 5274
# DEBUG:my_logger:Debug message 5275
# DEBUG:my_logger:Debug message 5276
# DEBUG:my_logger:Debug message 5277
# DEBUG:my_logger:Debug message 5278
# DEBUG:my_logger:Debug message 5279
# DEBUG:my_logger:Debug message 5280
# DEBUG:my_logger:Debug message 5281
# DEBUG:my_logger:Debug message 5282
# DEBUG:my_logger:Debug message 5283
# DEBUG:my_logger:Debug message 5284
# DEBUG:my_logger:Debug message 5285
# DEBUG:my_logger:Debug message 5286
# DEBUG:my_logger:Debug message 5287
# DEBUG:my_logger:Debug message 5288
# DEBUG:my_logger:Debug message 5289
# DEBUG:my_logger:Debug message 5290
# DEBUG:my_logger:Debug message 5291
# DEBUG:my_logger:Debug message 5292
# DEBUG:my_logger:Debug message 5293
# DEBUG:my_logger:Debug message 5294
# DEBUG:my_logger:Debug message 5295
# DEBUG:my_logger:Debug message 5296
# DEBUG:my_logger:Debug message 5297
# DEBUG:my_logger:Debug message 5298
# DEBUG:my_logger:Debug message 5299
# DEBUG:my_logger:Debug message 5300
# DEBUG:my_logger:Debug message 5301
# DEBUG:my_logger:Debug message 5302
# DEBUG:my_logger:Debug message 5303
# DEBUG:my_logger:Debug message 5304
# DEBUG:my_logger:Debug message 5305
# DEBUG:my_logger:Debug message 5306
# DEBUG:my_logger:Debug message 5307
# DEBUG:my_logger:Debug message 5308
# DEBUG:my_logger:Debug message 5309
# DEBUG:my_logger:Debug message 5310
# DEBUG:my_logger:Debug message 5311
# DEBUG:my_logger:Debug message 5312
# DEBUG:my_logger:Debug message 5313
# DEBUG:my_logger:Debug message 5314
# DEBUG:my_logger:Debug message 5315
# DEBUG:my_logger:Debug message 5316
# DEBUG:my_logger:Debug message 5317
# DEBUG:my_logger:Debug message 5318
# DEBUG:my_logger:Debug message 5319
# DEBUG:my_logger:Debug message 5320
# DEBUG:my_logger:Debug message 5321
# DEBUG:my_logger:Debug message 5322
# DEBUG:my_logger:Debug message 5323
# DEBUG:my_logger:Debug message 5324
# DEBUG:my_logger:Debug message 5325
# DEBUG:my_logger:Debug message 5326
# DEBUG:my_logger:Debug message 5327
# DEBUG:my_logger:Debug message 5328
# DEBUG:my_logger:Debug message 5329
# DEBUG:my_logger:Debug message 5330
# DEBUG:my_logger:Debug message 5331
# DEBUG:my_logger:Debug message 5332
# DEBUG:my_logger:Debug message 5333
# DEBUG:my_logger:Debug message 5334
# DEBUG:my_logger:Debug message 5335
# DEBUG:my_logger:Debug message 5336
# DEBUG:my_logger:Debug message 5337
# DEBUG:my_logger:Debug message 5338
# DEBUG:my_logger:Debug message 5339
# DEBUG:my_logger:Debug message 5340
# DEBUG:my_logger:Debug message 5341
# DEBUG:my_logger:Debug message 5342
# DEBUG:my_logger:Debug message 5343
# DEBUG:my_logger:Debug message 5344
# DEBUG:my_logger:Debug message 5345
# DEBUG:my_logger:Debug message 5346
# DEBUG:my_logger:Debug message 5347
# DEBUG:my_logger:Debug message 5348
# DEBUG:my_logger:Debug message 5349
# DEBUG:my_logger:Debug message 5350
# DEBUG:my_logger:Debug message 5351
# DEBUG:my_logger:Debug message 5352
# DEBUG:my_logger:Debug message 5353
# DEBUG:my_logger:Debug message 5354
# DEBUG:my_logger:Debug message 5355
# DEBUG:my_logger:Debug message 5356
# DEBUG:my_logger:Debug message 5357
# DEBUG:my_logger:Debug message 5358
# DEBUG:my_logger:Debug message 5359
# DEBUG:my_logger:Debug message 5360
# DEBUG:my_logger:Debug message 5361
# DEBUG:my_logger:Debug message 5362
# DEBUG:my_logger:Debug message 5363
# DEBUG:my_logger:Debug message 5364
# DEBUG:my_logger:Debug message 5365
# DEBUG:my_logger:Debug message 5366
# DEBUG:my_logger:Debug message 5367
# DEBUG:my_logger:Debug message 5368
# DEBUG:my_logger:Debug message 5369
# DEBUG:my_logger:Debug message 5370
# DEBUG:my_logger:Debug message 5371
# DEBUG:my_logger:Debug message 5372
# DEBUG:my_logger:Debug message 5373
# DEBUG:my_logger:Debug message 5374
# DEBUG:my_logger:Debug message 5375
# DEBUG:my_logger:Debug message 5376
# DEBUG:my_logger:Debug message 5377
# DEBUG:my_logger:Debug message 5378
# DEBUG:my_logger:Debug message 5379
# DEBUG:my_logger:Debug message 5380
# DEBUG:my_logger:Debug message 5381
# DEBUG:my_logger:Debug message 5382
# DEBUG:my_logger:Debug message 5383
# DEBUG:my_logger:Debug message 5384
# DEBUG:my_logger:Debug message 5385
# DEBUG:my_logger:Debug message 5386
# DEBUG:my_logger:Debug message 5387
# DEBUG:my_logger:Debug message 5388
# DEBUG:my_logger:Debug message 5389
# DEBUG:my_logger:Debug message 5390
# DEBUG:my_logger:Debug message 5391
# DEBUG:my_logger:Debug message 5392
# DEBUG:my_logger:Debug message 5393
# DEBUG:my_logger:Debug message 5394
# DEBUG:my_logger:Debug message 5395
# DEBUG:my_logger:Debug message 5396
# DEBUG:my_logger:Debug message 5397
# DEBUG:my_logger:Debug message 5398
# DEBUG:my_logger:Debug message 5399
# DEBUG:my_logger:Debug message 5400
# DEBUG:my_logger:Debug message 5401
# DEBUG:my_logger:Debug message 5402
# DEBUG:my_logger:Debug message 5403
# DEBUG:my_logger:Debug message 5404
# DEBUG:my_logger:Debug message 5405
# DEBUG:my_logger:Debug message 5406
# DEBUG:my_logger:Debug message 5407
# DEBUG:my_logger:Debug message 5408
# DEBUG:my_logger:Debug message 5409
# DEBUG:my_logger:Debug message 5410
# DEBUG:my_logger:Debug message 5411
# DEBUG:my_logger:Debug message 5412
# DEBUG:my_logger:Debug message 5413
# DEBUG:my_logger:Debug message 5414
# DEBUG:my_logger:Debug message 5415
# DEBUG:my_logger:Debug message 5416
# DEBUG:my_logger:Debug message 5417
# DEBUG:my_logger:Debug message 5418
# DEBUG:my_logger:Debug message 5419
# DEBUG:my_logger:Debug message 5420
# DEBUG:my_logger:Debug message 5421
# DEBUG:my_logger:Debug message 5422
# DEBUG:my_logger:Debug message 5423
# DEBUG:my_logger:Debug message 5424
# DEBUG:my_logger:Debug message 5425
# DEBUG:my_logger:Debug message 5426
# DEBUG:my_logger:Debug message 5427
# DEBUG:my_logger:Debug message 5428
# DEBUG:my_logger:Debug message 5429
# DEBUG:my_logger:Debug message 5430
# DEBUG:my_logger:Debug message 5431
# DEBUG:my_logger:Debug message 5432
# DEBUG:my_logger:Debug message 5433
# DEBUG:my_logger:Debug message 5434
# DEBUG:my_logger:Debug message 5435
# DEBUG:my_logger:Debug message 5436
# DEBUG:my_logger:Debug message 5437
# DEBUG:my_logger:Debug message 5438
# DEBUG:my_logger:Debug message 5439
# DEBUG:my_logger:Debug message 5440
# DEBUG:my_logger:Debug message 5441
# DEBUG:my_logger:Debug message 5442
# DEBUG:my_logger:Debug message 5443
# DEBUG:my_logger:Debug message 5444
# DEBUG:my_logger:Debug message 5445
# DEBUG:my_logger:Debug message 5446
# DEBUG:my_logger:Debug message 5447
# DEBUG:my_logger:Debug message 5448
# DEBUG:my_logger:Debug message 5449
# DEBUG:my_logger:Debug message 5450
# DEBUG:my_logger:Debug message 5451
# DEBUG:my_logger:Debug message 5452
# DEBUG:my_logger:Debug message 5453
# DEBUG:my_logger:Debug message 5454
# DEBUG:my_logger:Debug message 5455
# DEBUG:my_logger:Debug message 5456
# DEBUG:my_logger:Debug message 5457
# DEBUG:my_logger:Debug message 5458
# DEBUG:my_logger:Debug message 5459
# DEBUG:my_logger:Debug message 5460
# DEBUG:my_logger:Debug message 5461
# DEBUG:my_logger:Debug message 5462
# DEBUG:my_logger:Debug message 5463
# DEBUG:my_logger:Debug message 5464
# DEBUG:my_logger:Debug message 5465
# DEBUG:my_logger:Debug message 5466
# DEBUG:my_logger:Debug message 5467
# DEBUG:my_logger:Debug message 5468
# DEBUG:my_logger:Debug message 5469
# DEBUG:my_logger:Debug message 5470
# DEBUG:my_logger:Debug message 5471
# DEBUG:my_logger:Debug message 5472
# DEBUG:my_logger:Debug message 5473
# DEBUG:my_logger:Debug message 5474
# DEBUG:my_logger:Debug message 5475
# DEBUG:my_logger:Debug message 5476
# DEBUG:my_logger:Debug message 5477
# DEBUG:my_logger:Debug message 5478
# DEBUG:my_logger:Debug message 5479
# DEBUG:my_logger:Debug message 5480
# DEBUG:my_logger:Debug message 5481
# DEBUG:my_logger:Debug message 5482
# DEBUG:my_logger:Debug message 5483
# DEBUG:my_logger:Debug message 5484
# DEBUG:my_logger:Debug message 5485
# DEBUG:my_logger:Debug message 5486
# DEBUG:my_logger:Debug message 5487
# DEBUG:my_logger:Debug message 5488
# DEBUG:my_logger:Debug message 5489
# DEBUG:my_logger:Debug message 5490
# DEBUG:my_logger:Debug message 5491
# DEBUG:my_logger:Debug message 5492
# DEBUG:my_logger:Debug message 5493
# DEBUG:my_logger:Debug message 5494
# DEBUG:my_logger:Debug message 5495
# DEBUG:my_logger:Debug message 5496
# DEBUG:my_logger:Debug message 5497
# DEBUG:my_logger:Debug message 5498
# DEBUG:my_logger:Debug message 5499
# DEBUG:my_logger:Debug message 5500
# DEBUG:my_logger:Debug message 5501
# DEBUG:my_logger:Debug message 5502
# DEBUG:my_logger:Debug message 5503
# DEBUG:my_logger:Debug message 5504
# DEBUG:my_logger:Debug message 5505
# DEBUG:my_logger:Debug message 5506
# DEBUG:my_logger:Debug message 5507
# DEBUG:my_logger:Debug message 5508
# DEBUG:my_logger:Debug message 5509
# DEBUG:my_logger:Debug message 5510
# DEBUG:my_logger:Debug message 5511
# DEBUG:my_logger:Debug message 5512
# DEBUG:my_logger:Debug message 5513
# DEBUG:my_logger:Debug message 5514
# DEBUG:my_logger:Debug message 5515
# DEBUG:my_logger:Debug message 5516
# DEBUG:my_logger:Debug message 5517
# DEBUG:my_logger:Debug message 5518
# DEBUG:my_logger:Debug message 5519
# DEBUG:my_logger:Debug message 5520
# DEBUG:my_logger:Debug message 5521
# DEBUG:my_logger:Debug message 5522
# DEBUG:my_logger:Debug message 5523
# DEBUG:my_logger:Debug message 5524
# DEBUG:my_logger:Debug message 5525
# DEBUG:my_logger:Debug message 5526
# DEBUG:my_logger:Debug message 5527
# DEBUG:my_logger:Debug message 5528
# DEBUG:my_logger:Debug message 5529
# DEBUG:my_logger:Debug message 5530
# DEBUG:my_logger:Debug message 5531
# DEBUG:my_logger:Debug message 5532
# DEBUG:my_logger:Debug message 5533
# DEBUG:my_logger:Debug message 5534
# DEBUG:my_logger:Debug message 5535
# DEBUG:my_logger:Debug message 5536
# DEBUG:my_logger:Debug message 5537
# DEBUG:my_logger:Debug message 5538
# DEBUG:my_logger:Debug message 5539
# DEBUG:my_logger:Debug message 5540
# DEBUG:my_logger:Debug message 5541
# DEBUG:my_logger:Debug message 5542
# DEBUG:my_logger:Debug message 5543
# DEBUG:my_logger:Debug message 5544
# DEBUG:my_logger:Debug message 5545
# DEBUG:my_logger:Debug message 5546
# DEBUG:my_logger:Debug message 5547
# DEBUG:my_logger:Debug message 5548
# DEBUG:my_logger:Debug message 5549
# DEBUG:my_logger:Debug message 5550
# DEBUG:my_logger:Debug message 5551
# DEBUG:my_logger:Debug message 5552
# DEBUG:my_logger:Debug message 5553
# DEBUG:my_logger:Debug message 5554
# DEBUG:my_logger:Debug message 5555
# DEBUG:my_logger:Debug message 5556
# DEBUG:my_logger:Debug message 5557
# DEBUG:my_logger:Debug message 5558
# DEBUG:my_logger:Debug message 5559
# DEBUG:my_logger:Debug message 5560
# DEBUG:my_logger:Debug message 5561
# DEBUG:my_logger:Debug message 5562
# DEBUG:my_logger:Debug message 5563
# DEBUG:my_logger:Debug message 5564
# DEBUG:my_logger:Debug message 5565
# DEBUG:my_logger:Debug message 5566
# DEBUG:my_logger:Debug message 5567
# DEBUG:my_logger:Debug message 5568
# DEBUG:my_logger:Debug message 5569
# DEBUG:my_logger:Debug message 5570
# DEBUG:my_logger:Debug message 5571
# DEBUG:my_logger:Debug message 5572
# DEBUG:my_logger:Debug message 5573
# DEBUG:my_logger:Debug message 5574
# DEBUG:my_logger:Debug message 5575
# DEBUG:my_logger:Debug message 5576
# DEBUG:my_logger:Debug message 5577
# DEBUG:my_logger:Debug message 5578
# DEBUG:my_logger:Debug message 5579
# DEBUG:my_logger:Debug message 5580
# DEBUG:my_logger:Debug message 5581
# DEBUG:my_logger:Debug message 5582
# DEBUG:my_logger:Debug message 5583
# DEBUG:my_logger:Debug message 5584
# DEBUG:my_logger:Debug message 5585
# DEBUG:my_logger:Debug message 5586
# DEBUG:my_logger:Debug message 5587
# DEBUG:my_logger:Debug message 5588
# DEBUG:my_logger:Debug message 5589
# DEBUG:my_logger:Debug message 5590
# DEBUG:my_logger:Debug message 5591
# DEBUG:my_logger:Debug message 5592
# DEBUG:my_logger:Debug message 5593
# DEBUG:my_logger:Debug message 5594
# DEBUG:my_logger:Debug message 5595
# DEBUG:my_logger:Debug message 5596
# DEBUG:my_logger:Debug message 5597
# DEBUG:my_logger:Debug message 5598
# DEBUG:my_logger:Debug message 5599
# DEBUG:my_logger:Debug message 5600
# DEBUG:my_logger:Debug message 5601
# DEBUG:my_logger:Debug message 5602
# DEBUG:my_logger:Debug message 5603
# DEBUG:my_logger:Debug message 5604
# DEBUG:my_logger:Debug message 5605
# DEBUG:my_logger:Debug message 5606
# DEBUG:my_logger:Debug message 5607
# DEBUG:my_logger:Debug message 5608
# DEBUG:my_logger:Debug message 5609
# DEBUG:my_logger:Debug message 5610
# DEBUG:my_logger:Debug message 5611
# DEBUG:my_logger:Debug message 5612
# DEBUG:my_logger:Debug message 5613
# DEBUG:my_logger:Debug message 5614
# DEBUG:my_logger:Debug message 5615
# DEBUG:my_logger:Debug message 5616
# DEBUG:my_logger:Debug message 5617
# DEBUG:my_logger:Debug message 5618
# DEBUG:my_logger:Debug message 5619
# DEBUG:my_logger:Debug message 5620
# DEBUG:my_logger:Debug message 5621
# DEBUG:my_logger:Debug message 5622
# DEBUG:my_logger:Debug message 5623
# DEBUG:my_logger:Debug message 5624
# DEBUG:my_logger:Debug message 5625
# DEBUG:my_logger:Debug message 5626
# DEBUG:my_logger:Debug message 5627
# DEBUG:my_logger:Debug message 5628
# DEBUG:my_logger:Debug message 5629
# DEBUG:my_logger:Debug message 5630
# DEBUG:my_logger:Debug message 5631
# DEBUG:my_logger:Debug message 5632
# DEBUG:my_logger:Debug message 5633
# DEBUG:my_logger:Debug message 5634
# DEBUG:my_logger:Debug message 5635
# DEBUG:my_logger:Debug message 5636
# DEBUG:my_logger:Debug message 5637
# DEBUG:my_logger:Debug message 5638
# DEBUG:my_logger:Debug message 5639
# DEBUG:my_logger:Debug message 5640
# DEBUG:my_logger:Debug message 5641
# DEBUG:my_logger:Debug message 5642
# DEBUG:my_logger:Debug message 5643
# DEBUG:my_logger:Debug message 5644
# DEBUG:my_logger:Debug message 5645
# DEBUG:my_logger:Debug message 5646
# DEBUG:my_logger:Debug message 5647
# DEBUG:my_logger:Debug message 5648
# DEBUG:my_logger:Debug message 5649
# DEBUG:my_logger:Debug message 5650
# DEBUG:my_logger:Debug message 5651
# DEBUG:my_logger:Debug message 5652
# DEBUG:my_logger:Debug message 5653
# DEBUG:my_logger:Debug message 5654
# DEBUG:my_logger:Debug message 5655
# DEBUG:my_logger:Debug message 5656
# DEBUG:my_logger:Debug message 5657
# DEBUG:my_logger:Debug message 5658
# DEBUG:my_logger:Debug message 5659
# DEBUG:my_logger:Debug message 5660
# DEBUG:my_logger:Debug message 5661
# DEBUG:my_logger:Debug message 5662
# DEBUG:my_logger:Debug message 5663
# DEBUG:my_logger:Debug message 5664
# DEBUG:my_logger:Debug message 5665
# DEBUG:my_logger:Debug message 5666
# DEBUG:my_logger:Debug message 5667
# DEBUG:my_logger:Debug message 5668
# DEBUG:my_logger:Debug message 5669
# DEBUG:my_logger:Debug message 5670
# DEBUG:my_logger:Debug message 5671
# DEBUG:my_logger:Debug message 5672
# DEBUG:my_logger:Debug message 5673
# DEBUG:my_logger:Debug message 5674
# DEBUG:my_logger:Debug message 5675
# DEBUG:my_logger:Debug message 5676
# DEBUG:my_logger:Debug message 5677
# DEBUG:my_logger:Debug message 5678
# DEBUG:my_logger:Debug message 5679
# DEBUG:my_logger:Debug message 5680
# DEBUG:my_logger:Debug message 5681
# DEBUG:my_logger:Debug message 5682
# DEBUG:my_logger:Debug message 5683
# DEBUG:my_logger:Debug message 5684
# DEBUG:my_logger:Debug message 5685
# DEBUG:my_logger:Debug message 5686
# DEBUG:my_logger:Debug message 5687
# DEBUG:my_logger:Debug message 5688
# DEBUG:my_logger:Debug message 5689
# DEBUG:my_logger:Debug message 5690
# DEBUG:my_logger:Debug message 5691
# DEBUG:my_logger:Debug message 5692
# DEBUG:my_logger:Debug message 5693
# DEBUG:my_logger:Debug message 5694
# DEBUG:my_logger:Debug message 5695
# DEBUG:my_logger:Debug message 5696
# DEBUG:my_logger:Debug message 5697
# DEBUG:my_logger:Debug message 5698
# DEBUG:my_logger:Debug message 5699
# DEBUG:my_logger:Debug message 5700
# DEBUG:my_logger:Debug message 5701
# DEBUG:my_logger:Debug message 5702
# DEBUG:my_logger:Debug message 5703
# DEBUG:my_logger:Debug message 5704
# DEBUG:my_logger:Debug message 5705
# DEBUG:my_logger:Debug message 5706
# DEBUG:my_logger:Debug message 5707
# DEBUG:my_logger:Debug message 5708
# DEBUG:my_logger:Debug message 5709
# DEBUG:my_logger:Debug message 5710
# DEBUG:my_logger:Debug message 5711
# DEBUG:my_logger:Debug message 5712
# DEBUG:my_logger:Debug message 5713
# DEBUG:my_logger:Debug message 5714
# DEBUG:my_logger:Debug message 5715
# DEBUG:my_logger:Debug message 5716
# DEBUG:my_logger:Debug message 5717
# DEBUG:my_logger:Debug message 5718
# DEBUG:my_logger:Debug message 5719
# DEBUG:my_logger:Debug message 5720
# DEBUG:my_logger:Debug message 5721
# DEBUG:my_logger:Debug message 5722
# DEBUG:my_logger:Debug message 5723
# DEBUG:my_logger:Debug message 5724
# DEBUG:my_logger:Debug message 5725
# DEBUG:my_logger:Debug message 5726
# DEBUG:my_logger:Debug message 5727
# DEBUG:my_logger:Debug message 5728
# DEBUG:my_logger:Debug message 5729
# DEBUG:my_logger:Debug message 5730
# DEBUG:my_logger:Debug message 5731
# DEBUG:my_logger:Debug message 5732
# DEBUG:my_logger:Debug message 5733
# DEBUG:my_logger:Debug message 5734
# DEBUG:my_logger:Debug message 5735
# DEBUG:my_logger:Debug message 5736
# DEBUG:my_logger:Debug message 5737
# DEBUG:my_logger:Debug message 5738
# DEBUG:my_logger:Debug message 5739
# DEBUG:my_logger:Debug message 5740
# DEBUG:my_logger:Debug message 5741
# DEBUG:my_logger:Debug message 5742
# DEBUG:my_logger:Debug message 5743
# DEBUG:my_logger:Debug message 5744
# DEBUG:my_logger:Debug message 5745
# DEBUG:my_logger:Debug message 5746
# DEBUG:my_logger:Debug message 5747
# DEBUG:my_logger:Debug message 5748
# DEBUG:my_logger:Debug message 5749
# DEBUG:my_logger:Debug message 5750
# DEBUG:my_logger:Debug message 5751
# DEBUG:my_logger:Debug message 5752
# DEBUG:my_logger:Debug message 5753
# DEBUG:my_logger:Debug message 5754
# DEBUG:my_logger:Debug message 5755
# DEBUG:my_logger:Debug message 5756
# DEBUG:my_logger:Debug message 5757
# DEBUG:my_logger:Debug message 5758
# DEBUG:my_logger:Debug message 5759
# DEBUG:my_logger:Debug message 5760
# DEBUG:my_logger:Debug message 5761
# DEBUG:my_logger:Debug message 5762
# DEBUG:my_logger:Debug message 5763
# DEBUG:my_logger:Debug message 5764
# DEBUG:my_logger:Debug message 5765
# DEBUG:my_logger:Debug message 5766
# DEBUG:my_logger:Debug message 5767
# DEBUG:my_logger:Debug message 5768
# DEBUG:my_logger:Debug message 5769
# DEBUG:my_logger:Debug message 5770
# DEBUG:my_logger:Debug message 5771
# DEBUG:my_logger:Debug message 5772
# DEBUG:my_logger:Debug message 5773
# DEBUG:my_logger:Debug message 5774
# DEBUG:my_logger:Debug message 5775
# DEBUG:my_logger:Debug message 5776
# DEBUG:my_logger:Debug message 5777
# DEBUG:my_logger:Debug message 5778
# DEBUG:my_logger:Debug message 5779
# DEBUG:my_logger:Debug message 5780
# DEBUG:my_logger:Debug message 5781
# DEBUG:my_logger:Debug message 5782
# DEBUG:my_logger:Debug message 5783
# DEBUG:my_logger:Debug message 5784
# DEBUG:my_logger:Debug message 5785
# DEBUG:my_logger:Debug message 5786
# DEBUG:my_logger:Debug message 5787
# DEBUG:my_logger:Debug message 5788
# DEBUG:my_logger:Debug message 5789
# DEBUG:my_logger:Debug message 5790
# DEBUG:my_logger:Debug message 5791
# DEBUG:my_logger:Debug message 5792
# DEBUG:my_logger:Debug message 5793
# DEBUG:my_logger:Debug message 5794
# DEBUG:my_logger:Debug message 5795
# DEBUG:my_logger:Debug message 5796
# DEBUG:my_logger:Debug message 5797
# DEBUG:my_logger:Debug message 5798
# DEBUG:my_logger:Debug message 5799
# DEBUG:my_logger:Debug message 5800
# DEBUG:my_logger:Debug message 5801
# DEBUG:my_logger:Debug message 5802
# DEBUG:my_logger:Debug message 5803
# DEBUG:my_logger:Debug message 5804
# DEBUG:my_logger:Debug message 5805
# DEBUG:my_logger:Debug message 5806
# DEBUG:my_logger:Debug message 5807
# DEBUG:my_logger:Debug message 5808
# DEBUG:my_logger:Debug message 5809
# DEBUG:my_logger:Debug message 5810
# DEBUG:my_logger:Debug message 5811
# DEBUG:my_logger:Debug message 5812
# DEBUG:my_logger:Debug message 5813
# DEBUG:my_logger:Debug message 5814
# DEBUG:my_logger:Debug message 5815
# DEBUG:my_logger:Debug message 5816
# DEBUG:my_logger:Debug message 5817
# DEBUG:my_logger:Debug message 5818
# DEBUG:my_logger:Debug message 5819
# DEBUG:my_logger:Debug message 5820
# DEBUG:my_logger:Debug message 5821
# DEBUG:my_logger:Debug message 5822
# DEBUG:my_logger:Debug message 5823
# DEBUG:my_logger:Debug message 5824
# DEBUG:my_logger:Debug message 5825
# DEBUG:my_logger:Debug message 5826
# DEBUG:my_logger:Debug message 5827
# DEBUG:my_logger:Debug message 5828
# DEBUG:my_logger:Debug message 5829
# DEBUG:my_logger:Debug message 5830
# DEBUG:my_logger:Debug message 5831
# DEBUG:my_logger:Debug message 5832
# DEBUG:my_logger:Debug message 5833
# DEBUG:my_logger:Debug message 5834
# DEBUG:my_logger:Debug message 5835
# DEBUG:my_logger:Debug message 5836
# DEBUG:my_logger:Debug message 5837
# DEBUG:my_logger:Debug message 5838
# DEBUG:my_logger:Debug message 5839
# DEBUG:my_logger:Debug message 5840
# DEBUG:my_logger:Debug message 5841
# DEBUG:my_logger:Debug message 5842
# DEBUG:my_logger:Debug message 5843
# DEBUG:my_logger:Debug message 5844
# DEBUG:my_logger:Debug message 5845
# DEBUG:my_logger:Debug message 5846
# DEBUG:my_logger:Debug message 5847
# DEBUG:my_logger:Debug message 5848
# DEBUG:my_logger:Debug message 5849
# DEBUG:my_logger:Debug message 5850
# DEBUG:my_logger:Debug message 5851
# DEBUG:my_logger:Debug message 5852
# DEBUG:my_logger:Debug message 5853
# DEBUG:my_logger:Debug message 5854
# DEBUG:my_logger:Debug message 5855
# DEBUG:my_logger:Debug message 5856
# DEBUG:my_logger:Debug message 5857
# DEBUG:my_logger:Debug message 5858
# DEBUG:my_logger:Debug message 5859
# DEBUG:my_logger:Debug message 5860
# DEBUG:my_logger:Debug message 5861
# DEBUG:my_logger:Debug message 5862
# DEBUG:my_logger:Debug message 5863
# DEBUG:my_logger:Debug message 5864
# DEBUG:my_logger:Debug message 5865
# DEBUG:my_logger:Debug message 5866
# DEBUG:my_logger:Debug message 5867
# DEBUG:my_logger:Debug message 5868
# DEBUG:my_logger:Debug message 5869
# DEBUG:my_logger:Debug message 5870
# DEBUG:my_logger:Debug message 5871
# DEBUG:my_logger:Debug message 5872
# DEBUG:my_logger:Debug message 5873
# DEBUG:my_logger:Debug message 5874
# DEBUG:my_logger:Debug message 5875
# DEBUG:my_logger:Debug message 5876
# DEBUG:my_logger:Debug message 5877
# DEBUG:my_logger:Debug message 5878
# DEBUG:my_logger:Debug message 5879
# DEBUG:my_logger:Debug message 5880
# DEBUG:my_logger:Debug message 5881
# DEBUG:my_logger:Debug message 5882
# DEBUG:my_logger:Debug message 5883
# DEBUG:my_logger:Debug message 5884
# DEBUG:my_logger:Debug message 5885
# DEBUG:my_logger:Debug message 5886
# DEBUG:my_logger:Debug message 5887
# DEBUG:my_logger:Debug message 5888
# DEBUG:my_logger:Debug message 5889
# DEBUG:my_logger:Debug message 5890
# DEBUG:my_logger:Debug message 5891
# DEBUG:my_logger:Debug message 5892
# DEBUG:my_logger:Debug message 5893
# DEBUG:my_logger:Debug message 5894
# DEBUG:my_logger:Debug message 5895
# DEBUG:my_logger:Debug message 5896
# DEBUG:my_logger:Debug message 5897
# DEBUG:my_logger:Debug message 5898
# DEBUG:my_logger:Debug message 5899
# DEBUG:my_logger:Debug message 5900
# DEBUG:my_logger:Debug message 5901
# DEBUG:my_logger:Debug message 5902
# DEBUG:my_logger:Debug message 5903
# DEBUG:my_logger:Debug message 5904
# DEBUG:my_logger:Debug message 5905
# DEBUG:my_logger:Debug message 5906
# DEBUG:my_logger:Debug message 5907
# DEBUG:my_logger:Debug message 5908
# DEBUG:my_logger:Debug message 5909
# DEBUG:my_logger:Debug message 5910
# DEBUG:my_logger:Debug message 5911
# DEBUG:my_logger:Debug message 5912
# DEBUG:my_logger:Debug message 5913
# DEBUG:my_logger:Debug message 5914
# DEBUG:my_logger:Debug message 5915
# DEBUG:my_logger:Debug message 5916
# DEBUG:my_logger:Debug message 5917
# DEBUG:my_logger:Debug message 5918
# DEBUG:my_logger:Debug message 5919
# DEBUG:my_logger:Debug message 5920
# DEBUG:my_logger:Debug message 5921
# DEBUG:my_logger:Debug message 5922
# DEBUG:my_logger:Debug message 5923
# DEBUG:my_logger:Debug message 5924
# DEBUG:my_logger:Debug message 5925
# DEBUG:my_logger:Debug message 5926
# DEBUG:my_logger:Debug message 5927
# DEBUG:my_logger:Debug message 5928
# DEBUG:my_logger:Debug message 5929
# DEBUG:my_logger:Debug message 5930
# DEBUG:my_logger:Debug message 5931
# DEBUG:my_logger:Debug message 5932
# DEBUG:my_logger:Debug message 5933
# DEBUG:my_logger:Debug message 5934
# DEBUG:my_logger:Debug message 5935
# DEBUG:my_logger:Debug message 5936
# DEBUG:my_logger:Debug message 5937
# DEBUG:my_logger:Debug message 5938
# DEBUG:my_logger:Debug message 5939
# DEBUG:my_logger:Debug message 5940
# DEBUG:my_logger:Debug message 5941
# DEBUG:my_logger:Debug message 5942
# DEBUG:my_logger:Debug message 5943
# DEBUG:my_logger:Debug message 5944
# DEBUG:my_logger:Debug message 5945
# DEBUG:my_logger:Debug message 5946
# DEBUG:my_logger:Debug message 5947
# DEBUG:my_logger:Debug message 5948
# DEBUG:my_logger:Debug message 5949
# DEBUG:my_logger:Debug message 5950
# DEBUG:my_logger:Debug message 5951
# DEBUG:my_logger:Debug message 5952
# DEBUG:my_logger:Debug message 5953
# DEBUG:my_logger:Debug message 5954
# DEBUG:my_logger:Debug message 5955
# DEBUG:my_logger:Debug message 5956
# DEBUG:my_logger:Debug message 5957
# DEBUG:my_logger:Debug message 5958
# DEBUG:my_logger:Debug message 5959
# DEBUG:my_logger:Debug message 5960
# DEBUG:my_logger:Debug message 5961
# DEBUG:my_logger:Debug message 5962
# DEBUG:my_logger:Debug message 5963
# DEBUG:my_logger:Debug message 5964
# DEBUG:my_logger:Debug message 5965
# DEBUG:my_logger:Debug message 5966
# DEBUG:my_logger:Debug message 5967
# DEBUG:my_logger:Debug message 5968
# DEBUG:my_logger:Debug message 5969
# DEBUG:my_logger:Debug message 5970
# DEBUG:my_logger:Debug message 5971
# DEBUG:my_logger:Debug message 5972
# DEBUG:my_logger:Debug message 5973
# DEBUG:my_logger:Debug message 5974
# DEBUG:my_logger:Debug message 5975
# DEBUG:my_logger:Debug message 5976
# DEBUG:my_logger:Debug message 5977
# DEBUG:my_logger:Debug message 5978
# DEBUG:my_logger:Debug message 5979
# DEBUG:my_logger:Debug message 5980
# DEBUG:my_logger:Debug message 5981
# DEBUG:my_logger:Debug message 5982
# DEBUG:my_logger:Debug message 5983
# DEBUG:my_logger:Debug message 5984
# DEBUG:my_logger:Debug message 5985
# DEBUG:my_logger:Debug message 5986
# DEBUG:my_logger:Debug message 5987
# DEBUG:my_logger:Debug message 5988
# DEBUG:my_logger:Debug message 5989
# DEBUG:my_logger:Debug message 5990
# DEBUG:my_logger:Debug message 5991
# DEBUG:my_logger:Debug message 5992
# DEBUG:my_logger:Debug message 5993
# DEBUG:my_logger:Debug message 5994
# DEBUG:my_logger:Debug message 5995
# DEBUG:my_logger:Debug message 5996
# DEBUG:my_logger:Debug message 5997
# DEBUG:my_logger:Debug message 5998
# DEBUG:my_logger:Debug message 5999
# DEBUG:my_logger:Debug message 6000
# DEBUG:my_logger:Debug message 6001
# DEBUG:my_logger:Debug message 6002
# DEBUG:my_logger:Debug message 6003
# DEBUG:my_logger:Debug message 6004
# DEBUG:my_logger:Debug message 6005
# DEBUG:my_logger:Debug message 6006
# DEBUG:my_logger:Debug message 6007
# DEBUG:my_logger:Debug message 6008
# DEBUG:my_logger:Debug message 6009
# DEBUG:my_logger:Debug message 6010
# DEBUG:my_logger:Debug message 6011
# DEBUG:my_logger:Debug message 6012
# DEBUG:my_logger:Debug message 6013
# DEBUG:my_logger:Debug message 6014
# DEBUG:my_logger:Debug message 6015
# DEBUG:my_logger:Debug message 6016
# DEBUG:my_logger:Debug message 6017
# DEBUG:my_logger:Debug message 6018
# DEBUG:my_logger:Debug message 6019
# DEBUG:my_logger:Debug message 6020
# DEBUG:my_logger:Debug message 6021
# DEBUG:my_logger:Debug message 6022
# DEBUG:my_logger:Debug message 6023
# DEBUG:my_logger:Debug message 6024
# DEBUG:my_logger:Debug message 6025
# DEBUG:my_logger:Debug message 6026
# DEBUG:my_logger:Debug message 6027
# DEBUG:my_logger:Debug message 6028
# DEBUG:my_logger:Debug message 6029
# DEBUG:my_logger:Debug message 6030
# DEBUG:my_logger:Debug message 6031
# DEBUG:my_logger:Debug message 6032
# DEBUG:my_logger:Debug message 6033
# DEBUG:my_logger:Debug message 6034
# DEBUG:my_logger:Debug message 6035
# DEBUG:my_logger:Debug message 6036
# DEBUG:my_logger:Debug message 6037
# DEBUG:my_logger:Debug message 6038
# DEBUG:my_logger:Debug message 6039
# DEBUG:my_logger:Debug message 6040
# DEBUG:my_logger:Debug message 6041
# DEBUG:my_logger:Debug message 6042
# DEBUG:my_logger:Debug message 6043
# DEBUG:my_logger:Debug message 6044
# DEBUG:my_logger:Debug message 6045
# DEBUG:my_logger:Debug message 6046
# DEBUG:my_logger:Debug message 6047
# DEBUG:my_logger:Debug message 6048
# DEBUG:my_logger:Debug message 6049
# DEBUG:my_logger:Debug message 6050
# DEBUG:my_logger:Debug message 6051
# DEBUG:my_logger:Debug message 6052
# DEBUG:my_logger:Debug message 6053
# DEBUG:my_logger:Debug message 6054
# DEBUG:my_logger:Debug message 6055
# DEBUG:my_logger:Debug message 6056
# DEBUG:my_logger:Debug message 6057
# DEBUG:my_logger:Debug message 6058
# DEBUG:my_logger:Debug message 6059
# DEBUG:my_logger:Debug message 6060
# DEBUG:my_logger:Debug message 6061
# DEBUG:my_logger:Debug message 6062
# DEBUG:my_logger:Debug message 6063
# DEBUG:my_logger:Debug message 6064
# DEBUG:my_logger:Debug message 6065
# DEBUG:my_logger:Debug message 6066
# DEBUG:my_logger:Debug message 6067
# DEBUG:my_logger:Debug message 6068
# DEBUG:my_logger:Debug message 6069
# DEBUG:my_logger:Debug message 6070
# DEBUG:my_logger:Debug message 6071
# DEBUG:my_logger:Debug message 6072
# DEBUG:my_logger:Debug message 6073
# DEBUG:my_logger:Debug message 6074
# DEBUG:my_logger:Debug message 6075
# DEBUG:my_logger:Debug message 6076
# DEBUG:my_logger:Debug message 6077
# DEBUG:my_logger:Debug message 6078
# DEBUG:my_logger:Debug message 6079
# DEBUG:my_logger:Debug message 6080
# DEBUG:my_logger:Debug message 6081
# DEBUG:my_logger:Debug message 6082
# DEBUG:my_logger:Debug message 6083
# DEBUG:my_logger:Debug message 6084
# DEBUG:my_logger:Debug message 6085
# DEBUG:my_logger:Debug message 6086
# DEBUG:my_logger:Debug message 6087
# DEBUG:my_logger:Debug message 6088
# DEBUG:my_logger:Debug message 6089
# DEBUG:my_logger:Debug message 6090
# DEBUG:my_logger:Debug message 6091
# DEBUG:my_logger:Debug message 6092
# DEBUG:my_logger:Debug message 6093
# DEBUG:my_logger:Debug message 6094
# DEBUG:my_logger:Debug message 6095
# DEBUG:my_logger:Debug message 6096
# DEBUG:my_logger:Debug message 6097
# DEBUG:my_logger:Debug message 6098
# DEBUG:my_logger:Debug message 6099
# DEBUG:my_logger:Debug message 6100
# DEBUG:my_logger:Debug message 6101
# DEBUG:my_logger:Debug message 6102
# DEBUG:my_logger:Debug message 6103
# DEBUG:my_logger:Debug message 6104
# DEBUG:my_logger:Debug message 6105
# DEBUG:my_logger:Debug message 6106
# DEBUG:my_logger:Debug message 6107
# DEBUG:my_logger:Debug message 6108
# DEBUG:my_logger:Debug message 6109
# DEBUG:my_logger:Debug message 6110
# DEBUG:my_logger:Debug message 6111
# DEBUG:my_logger:Debug message 6112
# DEBUG:my_logger:Debug message 6113
# DEBUG:my_logger:Debug message 6114
# DEBUG:my_logger:Debug message 6115
# DEBUG:my_logger:Debug message 6116
# DEBUG:my_logger:Debug message 6117
# DEBUG:my_logger:Debug message 6118
# DEBUG:my_logger:Debug message 6119
# DEBUG:my_logger:Debug message 6120
# DEBUG:my_logger:Debug message 6121
# DEBUG:my_logger:Debug message 6122
# DEBUG:my_logger:Debug message 6123
# DEBUG:my_logger:Debug message 6124
# DEBUG:my_logger:Debug message 6125
# DEBUG:my_logger:Debug message 6126
# DEBUG:my_logger:Debug message 6127
# DEBUG:my_logger:Debug message 6128
# DEBUG:my_logger:Debug message 6129
# DEBUG:my_logger:Debug message 6130
# DEBUG:my_logger:Debug message 6131
# DEBUG:my_logger:Debug message 6132
# DEBUG:my_logger:Debug message 6133
# DEBUG:my_logger:Debug message 6134
# DEBUG:my_logger:Debug message 6135
# DEBUG:my_logger:Debug message 6136
# DEBUG:my_logger:Debug message 6137
# DEBUG:my_logger:Debug message 6138
# DEBUG:my_logger:Debug message 6139
# DEBUG:my_logger:Debug message 6140
# DEBUG:my_logger:Debug message 6141
# DEBUG:my_logger:Debug message 6142
# DEBUG:my_logger:Debug message 6143
# DEBUG:my_logger:Debug message 6144
# DEBUG:my_logger:Debug message 6145
# DEBUG:my_logger:Debug message 6146
# DEBUG:my_logger:Debug message 6147
# DEBUG:my_logger:Debug message 6148
# DEBUG:my_logger:Debug message 6149
# DEBUG:my_logger:Debug message 6150
# DEBUG:my_logger:Debug message 6151
# DEBUG:my_logger:Debug message 6152
# DEBUG:my_logger:Debug message 6153
# DEBUG:my_logger:Debug message 6154
# DEBUG:my_logger:Debug message 6155
# DEBUG:my_logger:Debug message 6156
# DEBUG:my_logger:Debug message 6157
# DEBUG:my_logger:Debug message 6158
# DEBUG:my_logger:Debug message 6159
# DEBUG:my_logger:Debug message 6160
# DEBUG:my_logger:Debug message 6161
# DEBUG:my_logger:Debug message 6162
# DEBUG:my_logger:Debug message 6163
# DEBUG:my_logger:Debug message 6164
# DEBUG:my_logger:Debug message 6165
# DEBUG:my_logger:Debug message 6166
# DEBUG:my_logger:Debug message 6167
# DEBUG:my_logger:Debug message 6168
# DEBUG:my_logger:Debug message 6169
# DEBUG:my_logger:Debug message 6170
# DEBUG:my_logger:Debug message 6171
# DEBUG:my_logger:Debug message 6172
# DEBUG:my_logger:Debug message 6173
# DEBUG:my_logger:Debug message 6174
# DEBUG:my_logger:Debug message 6175
# DEBUG:my_logger:Debug message 6176
# DEBUG:my_logger:Debug message 6177
# DEBUG:my_logger:Debug message 6178
# DEBUG:my_logger:Debug message 6179
# DEBUG:my_logger:Debug message 6180
# DEBUG:my_logger:Debug message 6181
# DEBUG:my_logger:Debug message 6182
# DEBUG:my_logger:Debug message 6183
# DEBUG:my_logger:Debug message 6184
# DEBUG:my_logger:Debug message 6185
# DEBUG:my_logger:Debug message 6186
# DEBUG:my_logger:Debug message 6187
# DEBUG:my_logger:Debug message 6188
# DEBUG:my_logger:Debug message 6189
# DEBUG:my_logger:Debug message 6190
# DEBUG:my_logger:Debug message 6191
# DEBUG:my_logger:Debug message 6192
# DEBUG:my_logger:Debug message 6193
# DEBUG:my_logger:Debug message 6194
# DEBUG:my_logger:Debug message 6195
# DEBUG:my_logger:Debug message 6196
# DEBUG:my_logger:Debug message 6197
# DEBUG:my_logger:Debug message 6198
# DEBUG:my_logger:Debug message 6199
# DEBUG:my_logger:Debug message 6200
# DEBUG:my_logger:Debug message 6201
# DEBUG:my_logger:Debug message 6202
# DEBUG:my_logger:Debug message 6203
# DEBUG:my_logger:Debug message 6204
# DEBUG:my_logger:Debug message 6205
# DEBUG:my_logger:Debug message 6206
# DEBUG:my_logger:Debug message 6207
# DEBUG:my_logger:Debug message 6208
# DEBUG:my_logger:Debug message 6209
# DEBUG:my_logger:Debug message 6210
# DEBUG:my_logger:Debug message 6211
# DEBUG:my_logger:Debug message 6212
# DEBUG:my_logger:Debug message 6213
# DEBUG:my_logger:Debug message 6214
# DEBUG:my_logger:Debug message 6215
# DEBUG:my_logger:Debug message 6216
# DEBUG:my_logger:Debug message 6217
# DEBUG:my_logger:Debug message 6218
# DEBUG:my_logger:Debug message 6219
# DEBUG:my_logger:Debug message 6220
# DEBUG:my_logger:Debug message 6221
# DEBUG:my_logger:Debug message 6222
# DEBUG:my_logger:Debug message 6223
# DEBUG:my_logger:Debug message 6224
# DEBUG:my_logger:Debug message 6225
# DEBUG:my_logger:Debug message 6226
# DEBUG:my_logger:Debug message 6227
# DEBUG:my_logger:Debug message 6228
# DEBUG:my_logger:Debug message 6229
# DEBUG:my_logger:Debug message 6230
# DEBUG:my_logger:Debug message 6231
# DEBUG:my_logger:Debug message 6232
# DEBUG:my_logger:Debug message 6233
# DEBUG:my_logger:Debug message 6234
# DEBUG:my_logger:Debug message 6235
# DEBUG:my_logger:Debug message 6236
# DEBUG:my_logger:Debug message 6237
# DEBUG:my_logger:Debug message 6238
# DEBUG:my_logger:Debug message 6239
# DEBUG:my_logger:Debug message 6240
# DEBUG:my_logger:Debug message 6241
# DEBUG:my_logger:Debug message 6242
# DEBUG:my_logger:Debug message 6243
# DEBUG:my_logger:Debug message 6244
# DEBUG:my_logger:Debug message 6245
# DEBUG:my_logger:Debug message 6246
# DEBUG:my_logger:Debug message 6247
# DEBUG:my_logger:Debug message 6248
# DEBUG:my_logger:Debug message 6249
# DEBUG:my_logger:Debug message 6250
# DEBUG:my_logger:Debug message 6251
# DEBUG:my_logger:Debug message 6252
# DEBUG:my_logger:Debug message 6253
# DEBUG:my_logger:Debug message 6254
# DEBUG:my_logger:Debug message 6255
# DEBUG:my_logger:Debug message 6256
# DEBUG:my_logger:Debug message 6257
# DEBUG:my_logger:Debug message 6258
# DEBUG:my_logger:Debug message 6259
# DEBUG:my_logger:Debug message 6260
# DEBUG:my_logger:Debug message 6261
# DEBUG:my_logger:Debug message 6262
# DEBUG:my_logger:Debug message 6263
# DEBUG:my_logger:Debug message 6264
# DEBUG:my_logger:Debug message 6265
# DEBUG:my_logger:Debug message 6266
# DEBUG:my_logger:Debug message 6267
# DEBUG:my_logger:Debug message 6268
# DEBUG:my_logger:Debug message 6269
# DEBUG:my_logger:Debug message 6270
# DEBUG:my_logger:Debug message 6271
# DEBUG:my_logger:Debug message 6272
# DEBUG:my_logger:Debug message 6273
# DEBUG:my_logger:Debug message 6274
# DEBUG:my_logger:Debug message 6275
# DEBUG:my_logger:Debug message 6276
# DEBUG:my_logger:Debug message 6277
# DEBUG:my_logger:Debug message 6278
# DEBUG:my_logger:Debug message 6279
# DEBUG:my_logger:Debug message 6280
# DEBUG:my_logger:Debug message 6281
# DEBUG:my_logger:Debug message 6282
# DEBUG:my_logger:Debug message 6283
# DEBUG:my_logger:Debug message 6284
# DEBUG:my_logger:Debug message 6285
# DEBUG:my_logger:Debug message 6286
# DEBUG:my_logger:Debug message 6287
# DEBUG:my_logger:Debug message 6288
# DEBUG:my_logger:Debug message 6289
# DEBUG:my_logger:Debug message 6290
# DEBUG:my_logger:Debug message 6291
# DEBUG:my_logger:Debug message 6292
# DEBUG:my_logger:Debug message 6293
# DEBUG:my_logger:Debug message 6294
# DEBUG:my_logger:Debug message 6295
# DEBUG:my_logger:Debug message 6296
# DEBUG:my_logger:Debug message 6297
# DEBUG:my_logger:Debug message 6298
# DEBUG:my_logger:Debug message 6299
# DEBUG:my_logger:Debug message 6300
# DEBUG:my_logger:Debug message 6301
# DEBUG:my_logger:Debug message 6302
# DEBUG:my_logger:Debug message 6303
# DEBUG:my_logger:Debug message 6304
# DEBUG:my_logger:Debug message 6305
# DEBUG:my_logger:Debug message 6306
# DEBUG:my_logger:Debug message 6307
# DEBUG:my_logger:Debug message 6308
# DEBUG:my_logger:Debug message 6309
# DEBUG:my_logger:Debug message 6310
# DEBUG:my_logger:Debug message 6311
# DEBUG:my_logger:Debug message 6312
# DEBUG:my_logger:Debug message 6313
# DEBUG:my_logger:Debug message 6314
# DEBUG:my_logger:Debug message 6315
# DEBUG:my_logger:Debug message 6316
# DEBUG:my_logger:Debug message 6317
# DEBUG:my_logger:Debug message 6318
# DEBUG:my_logger:Debug message 6319
# DEBUG:my_logger:Debug message 6320
# DEBUG:my_logger:Debug message 6321
# DEBUG:my_logger:Debug message 6322
# DEBUG:my_logger:Debug message 6323
# DEBUG:my_logger:Debug message 6324
# DEBUG:my_logger:Debug message 6325
# DEBUG:my_logger:Debug message 6326
# DEBUG:my_logger:Debug message 6327
# DEBUG:my_logger:Debug message 6328
# DEBUG:my_logger:Debug message 6329
# DEBUG:my_logger:Debug message 6330
# DEBUG:my_logger:Debug message 6331
# DEBUG:my_logger:Debug message 6332
# DEBUG:my_logger:Debug message 6333
# DEBUG:my_logger:Debug message 6334
# DEBUG:my_logger:Debug message 6335
# DEBUG:my_logger:Debug message 6336
# DEBUG:my_logger:Debug message 6337
# DEBUG:my_logger:Debug message 6338
# DEBUG:my_logger:Debug message 6339
# DEBUG:my_logger:Debug message 6340
# DEBUG:my_logger:Debug message 6341
# DEBUG:my_logger:Debug message 6342
# DEBUG:my_logger:Debug message 6343
# DEBUG:my_logger:Debug message 6344
# DEBUG:my_logger:Debug message 6345
# DEBUG:my_logger:Debug message 6346
# DEBUG:my_logger:Debug message 6347
# DEBUG:my_logger:Debug message 6348
# DEBUG:my_logger:Debug message 6349
# DEBUG:my_logger:Debug message 6350
# DEBUG:my_logger:Debug message 6351
# DEBUG:my_logger:Debug message 6352
# DEBUG:my_logger:Debug message 6353
# DEBUG:my_logger:Debug message 6354
# DEBUG:my_logger:Debug message 6355
# DEBUG:my_logger:Debug message 6356
# DEBUG:my_logger:Debug message 6357
# DEBUG:my_logger:Debug message 6358
# DEBUG:my_logger:Debug message 6359
# DEBUG:my_logger:Debug message 6360
# DEBUG:my_logger:Debug message 6361
# DEBUG:my_logger:Debug message 6362
# DEBUG:my_logger:Debug message 6363
# DEBUG:my_logger:Debug message 6364
# DEBUG:my_logger:Debug message 6365
# DEBUG:my_logger:Debug message 6366
# DEBUG:my_logger:Debug message 6367
# DEBUG:my_logger:Debug message 6368
# ...
# DEBUG:my_logger:Debug message 9543
# DEBUG:my_logger:Debug message 9544
# DEBUG:my_logger:Debug message 9545
# DEBUG:my_logger:Debug message 9546
# DEBUG:my_logger:Debug message 9547
# DEBUG:my_logger:Debug message 9548
# DEBUG:my_logger:Debug message 9549
# DEBUG:my_logger:Debug message 9550
# DEBUG:my_logger:Debug message 9551
# DEBUG:my_logger:Debug message 9552
# DEBUG:my_logger:Debug message 9553
# DEBUG:my_logger:Debug message 9554
# DEBUG:my_logger:Debug message 9555
# DEBUG:my_logger:Debug message 9556
# DEBUG:my_logger:Debug message 9557
# DEBUG:my_logger:Debug message 9558
# DEBUG:my_logger:Debug message 9559
# DEBUG:my_logger:Debug message 9560
# DEBUG:my_logger:Debug message 9561
# DEBUG:my_logger:Debug message 9562
# DEBUG:my_logger:Debug message 9563
# DEBUG:my_logger:Debug message 9564
# DEBUG:my_logger:Debug message 9565
# DEBUG:my_logger:Debug message 9566
# DEBUG:my_logger:Debug message 9567
# DEBUG:my_logger:Debug message 9568
# DEBUG:my_logger:Debug message 9569
# DEBUG:my_logger:Debug message 9570
# DEBUG:my_logger:Debug message 9571
# DEBUG:my_logger:Debug message 9572
# DEBUG:my_logger:Debug message 9573
# DEBUG:my_logger:Debug message 9574
# DEBUG:my_logger:Debug message 9575
# DEBUG:my_logger:Debug message 9576
# DEBUG:my_logger:Debug message 9577
# DEBUG:my_logger:Debug message 9578
# DEBUG:my_logger:Debug message 9579
# DEBUG:my_logger:Debug message 9580
# DEBUG:my_logger:Debug message 9581
# DEBUG:my_logger:Debug message 9582
# DEBUG:my_logger:Debug message 9583
# DEBUG:my_logger:Debug message 9584
# DEBUG:my_logger:Debug message 9585
# DEBUG:my_logger:Debug message 9586
# DEBUG:my_logger:Debug message 9587
# DEBUG:my_logger:Debug message 9588
# DEBUG:my_logger:Debug message 9589
# DEBUG:my_logger:Debug message 9590
# DEBUG:my_logger:Debug message 9591
# DEBUG:my_logger:Debug message 9592
# DEBUG:my_logger:Debug message 9593
# DEBUG:my_logger:Debug message 9594
# DEBUG:my_logger:Debug message 9595
# DEBUG:my_logger:Debug message 9596
# DEBUG:my_logger:Debug message 9597
# DEBUG:my_logger:Debug message 9598
# DEBUG:my_logger:Debug message 9599
# DEBUG:my_logger:Debug message 9600
# DEBUG:my_logger:Debug message 9601
# DEBUG:my_logger:Debug message 9602
# DEBUG:my_logger:Debug message 9603
# DEBUG:my_logger:Debug message 9604
# DEBUG:my_logger:Debug message 9605
# DEBUG:my_logger:Debug message 9606
# DEBUG:my_logger:Debug message 9607
# DEBUG:my_logger:Debug message 9608
# DEBUG:my_logger:Debug message 9609
# DEBUG:my_logger:Debug message 9610
# DEBUG:my_logger:Debug message 9611
# DEBUG:my_logger:Debug message 9612
# DEBUG:my_logger:Debug message 9613
# DEBUG:my_logger:Debug message 9614
# DEBUG:my_logger:Debug message 9615
# DEBUG:my_logger:Debug message 9616
# DEBUG:my_logger:Debug message 9617
# DEBUG:my_logger:Debug message 9618
# DEBUG:my_logger:Debug message 9619
# DEBUG:my_logger:Debug message 9620
# DEBUG:my_logger:Debug message 9621
# DEBUG:my_logger:Debug message 9622
# DEBUG:my_logger:Debug message 9623
# DEBUG:my_logger:Debug message 9624
# DEBUG:my_logger:Debug message 9625
# DEBUG:my_logger:Debug message 9626
# DEBUG:my_logger:Debug message 9627
# DEBUG:my_logger:Debug message 9628
# DEBUG:my_logger:Debug message 9629
# DEBUG:my_logger:Debug message 9630
# DEBUG:my_logger:Debug message 9631
# DEBUG:my_logger:Debug message 9632
# DEBUG:my_logger:Debug message 9633
# DEBUG:my_logger:Debug message 9634
# DEBUG:my_logger:Debug message 9635
# DEBUG:my_logger:Debug message 9636
# DEBUG:my_logger:Debug message 9637
# DEBUG:my_logger:Debug message 9638
# DEBUG:my_logger:Debug message 9639
# DEBUG:my_logger:Debug message 9640
# DEBUG:my_logger:Debug message 9641
# DEBUG:my_logger:Debug message 9642
# DEBUG:my_logger:Debug message 9643
# DEBUG:my_logger:Debug message 9644
# DEBUG:my_logger:Debug message 9645
# DEBUG:my_logger:Debug message 9646
# DEBUG:my_logger:Debug message 9647
# DEBUG:my_logger:Debug message 9648
# DEBUG:my_logger:Debug message 9649
# DEBUG:my_logger:Debug message 9650
# DEBUG:my_logger:Debug message 9651
# DEBUG:my_logger:Debug message 9652
# DEBUG:my_logger:Debug message 9653
# DEBUG:my_logger:Debug message 9654
# DEBUG:my_logger:Debug message 9655
# DEBUG:my_logger:Debug message 9656
# DEBUG:my_logger:Debug message 9657
# DEBUG:my_logger:Debug message 9658
# DEBUG:my_logger:Debug message 9659
# DEBUG:my_logger:Debug message 9660
# DEBUG:my_logger:Debug message 9661
# DEBUG:my_logger:Debug message 9662
# DEBUG:my_logger:Debug message 9663
# DEBUG:my_logger:Debug message 9664
# DEBUG:my_logger:Debug message 9665
# DEBUG:my_logger:Debug message 9666
# DEBUG:my_logger:Debug message 9667
# DEBUG:my_logger:Debug message 9668
# DEBUG:my_logger:Debug message 9669
# DEBUG:my_logger:Debug message 9670
# DEBUG:my_logger:Debug message 9671
# DEBUG:my_logger:Debug message 9672
# DEBUG:my_logger:Debug message 9673
# DEBUG:my_logger:Debug message 9674
# DEBUG:my_logger:Debug message 9675
# DEBUG:my_logger:Debug message 9676
# DEBUG:my_logger:Debug message 9677
# DEBUG:my_logger:Debug message 9678
# DEBUG:my_logger:Debug message 9679
# DEBUG:my_logger:Debug message 9680
# DEBUG:my_logger:Debug message 9681
# DEBUG:my_logger:Debug message 9682
# DEBUG:my_logger:Debug message 9683
# DEBUG:my_logger:Debug message 9684
# DEBUG:my_logger:Debug message 9685
# DEBUG:my_logger:Debug message 9686
# DEBUG:my_logger:Debug message 9687
# DEBUG:my_logger:Debug message 9688
# DEBUG:my_logger:Debug message 9689
# DEBUG:my_logger:Debug message 9690
# DEBUG:my_logger:Debug message 9691
# DEBUG:my_logger:Debug message 9692
# DEBUG:my_logger:Debug message 9693
# DEBUG:my_logger:Debug message 9694
# DEBUG:my_logger:Debug message 9695
# DEBUG:my_logger:Debug message 9696
# DEBUG:my_logger:Debug message 9697
# DEBUG:my_logger:Debug message 9698
# DEBUG:my_logger:Debug message 9699
# DEBUG:my_logger:Debug message 9700
# DEBUG:my_logger:Debug message 9701
# DEBUG:my_logger:Debug message 9702
# DEBUG:my_logger:Debug message 9703
# DEBUG:my_logger:Debug message 9704
# DEBUG:my_logger:Debug message 9705
# DEBUG:my_logger:Debug message 9706
# DEBUG:my_logger:Debug message 9707
# DEBUG:my_logger:Debug message 9708
# DEBUG:my_logger:Debug message 9709
# DEBUG:my_logger:Debug message 9710
# DEBUG:my_logger:Debug message 9711
# DEBUG:my_logger:Debug message 9712
# DEBUG:my_logger:Debug message 9713
# DEBUG:my_logger:Debug message 9714
# DEBUG:my_logger:Debug message 9715
# DEBUG:my_logger:Debug message 9716
# DEBUG:my_logger:Debug message 9717
# DEBUG:my_logger:Debug message 9718
# DEBUG:my_logger:Debug message 9719
# DEBUG:my_logger:Debug message 9720
# DEBUG:my_logger:Debug message 9721
# DEBUG:my_logger:Debug message 9722
# DEBUG:my_logger:Debug message 9723
# DEBUG:my_logger:Debug message 9724
# DEBUG:my_logger:Debug message 9725
# DEBUG:my_logger:Debug message 9726
# DEBUG:my_logger:Debug message 9727
# DEBUG:my_logger:Debug message 9728
# DEBUG:my_logger:Debug message 9729
# DEBUG:my_logger:Debug message 9730
# DEBUG:my_logger:Debug message 9731
# DEBUG:my_logger:Debug message 9732
# DEBUG:my_logger:Debug message 9733
# DEBUG:my_logger:Debug message 9734
# DEBUG:my_logger:Debug message 9735
# DEBUG:my_logger:Debug message 9736
# DEBUG:my_logger:Debug message 9737
# DEBUG:my_logger:Debug message 9738
# DEBUG:my_logger:Debug message 9739
# DEBUG:my_logger:Debug message 9740
# DEBUG:my_logger:Debug message 9741
# DEBUG:my_logger:Debug message 9742
# DEBUG:my_logger:Debug message 9743
# DEBUG:my_logger:Debug message 9744
# DEBUG:my_logger:Debug message 9745
# DEBUG:my_logger:Debug message 9746
# DEBUG:my_logger:Debug message 9747
# DEBUG:my_logger:Debug message 9748
# DEBUG:my_logger:Debug message 9749
# DEBUG:my_logger:Debug message 9750
# DEBUG:my_logger:Debug message 9751
# DEBUG:my_logger:Debug message 9752
# DEBUG:my_logger:Debug message 9753
# DEBUG:my_logger:Debug message 9754
# DEBUG:my_logger:Debug message 9755
# DEBUG:my_logger:Debug message 9756
# DEBUG:my_logger:Debug message 9757
# DEBUG:my_logger:Debug message 9758
# DEBUG:my_logger:Debug message 9759
# DEBUG:my_logger:Debug message 9760
# DEBUG:my_logger:Debug message 9761
# DEBUG:my_logger:Debug message 9762
# DEBUG:my_logger:Debug message 9763
# DEBUG:my_logger:Debug message 9764
# DEBUG:my_logger:Debug message 9765
# DEBUG:my_logger:Debug message 9766
# DEBUG:my_logger:Debug message 9767
# DEBUG:my_logger:Debug message 9768
# DEBUG:my_logger:Debug message 9769
# DEBUG:my_logger:Debug message 9770
# DEBUG:my_logger:Debug message 9771
# DEBUG:my_logger:Debug message 9772
# DEBUG:my_logger:Debug message 9773
# DEBUG:my_logger:Debug message 9774
# DEBUG:my_logger:Debug message 9775
# DEBUG:my_logger:Debug message 9776
# DEBUG:my_logger:Debug message 9777
# DEBUG:my_logger:Debug message 9778
# DEBUG:my_logger:Debug message 9779
# DEBUG:my_logger:Debug message 9780
# DEBUG:my_logger:Debug message 9781
# DEBUG:my_logger:Debug message 9782
# DEBUG:my_logger:Debug message 9783
# DEBUG:my_logger:Debug message 9784
# DEBUG:my_logger:Debug message 9785
# DEBUG:my_logger:Debug message 9786
# DEBUG:my_logger:Debug message 9787
# DEBUG:my_logger:Debug message 9788
# DEBUG:my_logger:Debug message 9789
# DEBUG:my_logger:Debug message 9790
# DEBUG:my_logger:Debug message 9791
# DEBUG:my_logger:Debug message 9792
# DEBUG:my_logger:Debug message 9793
# DEBUG:my_logger:Debug message 9794
# DEBUG:my_logger:Debug message 9795
# DEBUG:my_logger:Debug message 9796
# DEBUG:my_logger:Debug message 9797
# DEBUG:my_logger:Debug message 9798
# DEBUG:my_logger:Debug message 9799
# DEBUG:my_logger:Debug message 9800
# DEBUG:my_logger:Debug message 9801
# DEBUG:my_logger:Debug message 9802
# DEBUG:my_logger:Debug message 9803
# DEBUG:my_logger:Debug message 9804
# DEBUG:my_logger:Debug message 9805
# DEBUG:my_logger:Debug message 9806
# DEBUG:my_logger:Debug message 9807
# DEBUG:my_logger:Debug message 9808
# DEBUG:my_logger:Debug message 9809
# DEBUG:my_logger:Debug message 9810
# DEBUG:my_logger:Debug message 9811
# DEBUG:my_logger:Debug message 9812
# DEBUG:my_logger:Debug message 9813
# DEBUG:my_logger:Debug message 9814
# DEBUG:my_logger:Debug message 9815
# DEBUG:my_logger:Debug message 9816
# DEBUG:my_logger:Debug message 9817
# DEBUG:my_logger:Debug message 9818
# DEBUG:my_logger:Debug message 9819
# DEBUG:my_logger:Debug message 9820
# DEBUG:my_logger:Debug message 9821
# DEBUG:my_logger:Debug message 9822
# DEBUG:my_logger:Debug message 9823
# DEBUG:my_logger:Debug message 9824
# DEBUG:my_logger:Debug message 9825
# DEBUG:my_logger:Debug message 9826
# DEBUG:my_logger:Debug message 9827
# DEBUG:my_logger:Debug message 9828
# DEBUG:my_logger:Debug message 9829
# DEBUG:my_logger:Debug message 9830
# DEBUG:my_logger:Debug message 9831
# DEBUG:my_logger:Debug message 9832
# DEBUG:my_logger:Debug message 9833
# DEBUG:my_logger:Debug message 9834
# DEBUG:my_logger:Debug message 9835
# DEBUG:my_logger:Debug message 9836
# DEBUG:my_logger:Debug message 9837
# DEBUG:my_logger:Debug message 9838
# DEBUG:my_logger:Debug message 9839
# DEBUG:my_logger:Debug message 9840
# DEBUG:my_logger:Debug message 9841
# DEBUG:my_logger:Debug message 9842
# DEBUG:my_logger:Debug message 9843
# DEBUG:my_logger:Debug message 9844
# DEBUG:my_logger:Debug message 9845
# DEBUG:my_logger:Debug message 9846
# DEBUG:my_logger:Debug message 9847
# DEBUG:my_logger:Debug message 9848
# DEBUG:my_logger:Debug message 9849
# DEBUG:my_logger:Debug message 9850
# DEBUG:my_logger:Debug message 9851
# DEBUG:my_logger:Debug message 9852
# DEBUG:my_logger:Debug message 9853
# DEBUG:my_logger:Debug message 9854
# DEBUG:my_logger:Debug message 9855
# DEBUG:my_logger:Debug message 9856
# DEBUG:my_logger:Debug message 9857
# DEBUG:my_logger:Debug message 9858
# DEBUG:my_logger:Debug message 9859
# DEBUG:my_logger:Debug message 9860
# DEBUG:my_logger:Debug message 9861
# DEBUG:my_logger:Debug message 9862
# DEBUG:my_logger:Debug message 9863
# DEBUG:my_logger:Debug message 9864
# DEBUG:my_logger:Debug message 9865
# DEBUG:my_logger:Debug message 9866
# DEBUG:my_logger:Debug message 9867
# DEBUG:my_logger:Debug message 9868
# DEBUG:my_logger:Debug message 9869
# DEBUG:my_logger:Debug message 9870
# DEBUG:my_logger:Debug message 9871
# DEBUG:my_logger:Debug message 9872
# DEBUG:my_logger:Debug message 9873
# DEBUG:my_logger:Debug message 9874
# DEBUG:my_logger:Debug message 9875
# DEBUG:my_logger:Debug message 9876
# DEBUG:my_logger:Debug message 9877
# DEBUG:my_logger:Debug message 9878
# DEBUG:my_logger:Debug message 9879
# DEBUG:my_logger:Debug message 9880
# DEBUG:my_logger:Debug message 9881
# DEBUG:my_logger:Debug message 9882
# DEBUG:my_logger:Debug message 9883
# DEBUG:my_logger:Debug message 9884
# DEBUG:my_logger:Debug message 9885
# DEBUG:my_logger:Debug message 9886
# DEBUG:my_logger:Debug message 9887
# DEBUG:my_logger:Debug message 9888
# DEBUG:my_logger:Debug message 9889
# DEBUG:my_logger:Debug message 9890
# DEBUG:my_logger:Debug message 9891
# DEBUG:my_logger:Debug message 9892
# DEBUG:my_logger:Debug message 9893
# DEBUG:my_logger:Debug message 9894
# DEBUG:my_logger:Debug message 9895
# DEBUG:my_logger:Debug message 9896
# DEBUG:my_logger:Debug message 9897
# DEBUG:my_logger:Debug message 9898
# DEBUG:my_logger:Debug message 9899
# DEBUG:my_logger:Debug message 9900
# DEBUG:my_logger:Debug message 9901
# DEBUG:my_logger:Debug message 9902
# DEBUG:my_logger:Debug message 9903
# DEBUG:my_logger:Debug message 9904
# DEBUG:my_logger:Debug message 9905
# DEBUG:my_logger:Debug message 9906
# DEBUG:my_logger:Debug message 9907
# DEBUG:my_logger:Debug message 9908
# DEBUG:my_logger:Debug message 9909
# DEBUG:my_logger:Debug message 9910
# DEBUG:my_logger:Debug message 9911
# DEBUG:my_logger:Debug message 9912
# DEBUG:my_logger:Debug message 9913
# DEBUG:my_logger:Debug message 9914
# DEBUG:my_logger:Debug message 9915
# DEBUG:my_logger:Debug message 9916
# DEBUG:my_logger:Debug message 9917
# DEBUG:my_logger:Debug message 9918
# DEBUG:my_logger:Debug message 9919
# DEBUG:my_logger:Debug message 9920
# DEBUG:my_logger:Debug message 9921
# DEBUG:my_logger:Debug message 9922
# DEBUG:my_logger:Debug message 9923
# DEBUG:my_logger:Debug message 9924
# DEBUG:my_logger:Debug message 9925
# DEBUG:my_logger:Debug message 9926
# DEBUG:my_logger:Debug message 9927
# DEBUG:my_logger:Debug message 9928
# DEBUG:my_logger:Debug message 9929
# DEBUG:my_logger:Debug message 9930
# DEBUG:my_logger:Debug message 9931
# DEBUG:my_logger:Debug message 9932
# DEBUG:my_logger:Debug message 9933
# DEBUG:my_logger:Debug message 9934
# DEBUG:my_logger:Debug message 9935
# DEBUG:my_logger:Debug message 9936
# DEBUG:my_logger:Debug message 9937
# DEBUG:my_logger:Debug message 9938
# DEBUG:my_logger:Debug message 9939
# DEBUG:my_logger:Debug message 9940
# DEBUG:my_logger:Debug message 9941
# DEBUG:my_logger:Debug message 9942
# DEBUG:my_logger:Debug message 9943
# DEBUG:my_logger:Debug message 9944
# DEBUG:my_logger:Debug message 9945
# DEBUG:my_logger:Debug message 9946
# DEBUG:my_logger:Debug message 9947
# DEBUG:my_logger:Debug message 9948
# DEBUG:my_logger:Debug message 9949
# DEBUG:my_logger:Debug message 9950
# DEBUG:my_logger:Debug message 9951
# DEBUG:my_logger:Debug message 9952
# DEBUG:my_logger:Debug message 9953
# DEBUG:my_logger:Debug message 9954
# DEBUG:my_logger:Debug message 9955
# DEBUG:my_logger:Debug message 9956
# DEBUG:my_logger:Debug message 9957
# DEBUG:my_logger:Debug message 9958
# DEBUG:my_logger:Debug message 9959
# DEBUG:my_logger:Debug message 9960
# DEBUG:my_logger:Debug message 9961
# DEBUG:my_logger:Debug message 9962
# DEBUG:my_logger:Debug message 9963
# DEBUG:my_logger:Debug message 9964
# DEBUG:my_logger:Debug message 9965
# DEBUG:my_logger:Debug message 9966
# DEBUG:my_logger:Debug message 9967
# DEBUG:my_logger:Debug message 9968
# DEBUG:my_logger:Debug message 9969
# DEBUG:my_logger:Debug message 9970
# DEBUG:my_logger:Debug message 9971
# DEBUG:my_logger:Debug message 9972
# DEBUG:my_logger:Debug message 9973
# DEBUG:my_logger:Debug message 9974
# DEBUG:my_logger:Debug message 9975
# DEBUG:my_logger:Debug message 9976
# DEBUG:my_logger:Debug message 9977
# DEBUG:my_logger:Debug message 9978
# DEBUG:my_logger:Debug message 9979
# DEBUG:my_logger:Debug message 9980
# DEBUG:my_logger:Debug message 9981
# DEBUG:my_logger:Debug message 9982
# DEBUG:my_logger:Debug message 9983
# DEBUG:my_logger:Debug message 9984
# DEBUG:my_logger:Debug message 9985
# DEBUG:my_logger:Debug message 9986
# DEBUG:my_logger:Debug message 9987
# DEBUG:my_logger:Debug message 9988
# DEBUG:my_logger:Debug message 9989
# DEBUG:my_logger:Debug message 9990
# DEBUG:my_logger:Debug message 9991
# DEBUG:my_logger:Debug message 9992
# DEBUG:my_logger:Debug message 9993
# DEBUG:my_logger:Debug message 9994
# DEBUG:my_logger:Debug message 9995
# DEBUG:my_logger:Debug message 9996
# DEBUG:my_logger:Debug message 9997
# DEBUG:my_logger:Debug message 9998
# DEBUG:my_logger:Debug message 9999

# %%
# Write a program that handles both IndexError and KeyError using a try-except block

# Sample list and dictionary
my_list = [10, 20, 30]
my_dict = {'name': 'Anas', 'age': 21}

try:
    # Try to access an index that might be out of range
    print("List item:", my_list[5])

    # Try to access a key that might not exist
    print("Student grade:", my_dict['grade'])

except IndexError:
    print("Error: List index is out of range.")

except KeyError:
    print("Error: Dictionary key not found.")
# Out:
# Error: List index is out of range.

# %%
# How would you open a file and read its contents using a context manager in Python

with open('example.txt', 'r') as file:
    content = file.read()
    print("File content:")
    print(content)
# Out:
# File content:
# Hello, this is a sample text.This is a new line added to the file.
# This is a new line added to the file.

# %%
#  Write a Python program that reads a file and prints the number of occurrences of a specific word

# Ask the user for the word to search
word_to_search = input("Enter the word to count: ").lower()

try:
    with open('example.txt', 'r') as file:
        content = file.read().lower()  # Convert content to lowercase for case-insensitive search
        word_count = content.split().count(word_to_search)
        print(f"The word '{word_to_search}' appears {word_count} times in the file.")
except FileNotFoundError:
    print("Error: The file 'example.txt' was not found.")
except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter the word to count: python
# The word 'python' appears 0 times in the file.

# %%
# How can you check if a file is empty before attempting to read its contents

import os

file_path = 'example.txt'

if os.path.exists(file_path):
    if os.path.getsize(file_path) == 0:
        print("The file is empty.")
    else:
        with open(file_path, 'r') as file:
            content = file.read()
            print("File content:")
            print(content)
else:
    print("The file does not exist.")
# Out:
# File content:
# Hello, this is a sample text.This is a new line added to the file.
# This is a new line added to the file.

# %%
# Write a Python program that writes to a log file when an error occurs during file handling

import logging

# Configure logging to write errors to a log file
logging.basicConfig(
    filename='file_errors.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

file_name = 'example.txt'

try:
    with open(file_name, 'r') as file:
        content = file.read()
        print("File content:")
        print(content)

except FileNotFoundError as e:
    print("Error: File not found.")
    logging.error(f"FileNotFoundError: {e}")

except PermissionError as e:
    print("Error: You don't have permission to read this file.")
    logging.error(f"PermissionError: {e}")

except Exception as e:
    print("An unexpected error occurred.")
    logging.error(f"Unexpected error: {e}")
# Out:
# File content:
# Hello, this is a sample text.This is a new line added to the file.
# This is a new line added to the file.
